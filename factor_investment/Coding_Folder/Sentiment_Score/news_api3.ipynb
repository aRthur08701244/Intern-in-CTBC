# %%
import requests
import time
import json
from datetime import datetime
from lxml import etree
import csv
import pandas as pd
import numpy as np
import os
from wakepy import set_keepawake, unset_keepawake

set_keepawake(keep_screen_awake=True)

os.chdir('/Users/arthur/Desktop/factor_investment/202202_Intern/data')

# %%
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.102 Safari/537.36 Edge/18.18362',
    }

cnyes_news = pd.DataFrame(columns=['date', 'title', 'content'])    

#將資料儲存成CSV檔案
# def savefile(beginday,stopday,news):
#     filename='cnyes-'+beginday+'~'+stopday+'.csv'
#     with open(filename, 'a', newline='',encoding='utf8') as csvfile:
#         writer = csv.writer(csvfile, delimiter=',')
#         writer.writerow(news)

#分析網頁資訊
def parse(headers,newsID,k,total,beginday,stopday):    
    fnews_url = 'https://news.cnyes.com/news/id/{}?exp=a'.format(newsID) #原始新聞網址    
    response = requests.get(fnews_url, headers)
    html=etree.HTML(response.content)   
    try: 
        title=html.xpath('//*[@id="content"]/div/div/div[2]/main/div[2]/h1/text()')[0] #新聞標題     
        posttime=html.xpath('//*[@id="content"]/div/div/div[2]/main/div[2]/div[2]/time/text()')[0] 
        posttime=posttime.split(' ')
        date=posttime[0]#新聞發佈日期
        time=posttime[1]#新聞發佈時間
        content=html.xpath('//*[@id="content"]/div/div/div[2]/main/div[3]/article/section/div[2]/div[1]/p/text()')
        content=''.join(content).strip() #新聞內文
        content=content.replace('\n','')
        url=fnews_url.replace('?exp=a','')#原始新聞來源網址
        tag=html.xpath('//*[@id="content"]/div/div/div[2]/main/div[3]/article/section/nav[2]/a//text()')
        tag=','.join(tag).strip() #Tag
#         news=[date,time,title,tag,content,url]
#         new_row = {'date'=date, 'title'=title, 'content'=content}
        cnyes_news.loc[cnyes_news.shape[0], 'date'] = date
        cnyes_news.loc[cnyes_news.shape[0]-1, 'title'] = title
        cnyes_news.loc[cnyes_news.shape[0]-1, 'content'] = content
        if (k % 100) == 0:
            print('第 {} / {} 篇新聞: '.format(k,total))
#         print("news:",news)
        
    except:
        print('')
        #將資訊儲存成檔案(或寫入資料庫)
#         savefile(beginday,stopday,news) # ?????????????
        
#     except IndexError as IE:
#         print('抓值範圍錯誤')
#         print('html:' ,response.text)
#         news={"title":None,"date":None,"content":None,"url":None,"tag":None }
#     except OSError as OSErr:
#         print('OSError:{}'.format(OSErr))
#     except requests.exceptions.ConnectionError as REC:
#         print('連線錯誤')
#     except urllib3.exceptions.ProtocolError as UEP:
#         print('連線錯誤')
#     return news

#分析文章數量
def crawler(beginday,stopday):   
    #搜尋新聞開始日,格式為 'Y-M-D'
    be_day=beginday
    #搜尋新聞結束日
    st_day=stopday
    #日期格式轉換成時間戳型式
    startday = int(datetime.timestamp(datetime.strptime(be_day, "%Y-%m-%d")))
    endday = int(datetime.timestamp(datetime.strptime(st_day, "%Y-%m-%d"))-1)
    url ='https://news.cnyes.com/api/v3/news/category/tw_stock?startAt={}&endAt={}&limit=30'.format(startday,endday)
    res = requests.get(url, headers)

    newsID_lt=[]
    #獲取搜尋總頁數
    last_page = json.loads(res.text)['items']['last_page']
    print('總共 {} 頁'.format(last_page))
    # 篩選 newsId 值
    newsIDlist=json.loads(res.text)['items']['data']

    #獲取第一頁各個新聞的 newsId
    for i in newsIDlist:
        newsID=i['newsId']
        newsID_lt.append(newsID)
#     print('正在獲取第 1 頁 newsId') #########################
#     time.sleep(1) ????????????????????????????????????

    #進行翻頁並獲取各頁面的 newsId
    for p in range(2,last_page+1):
        oth_url ='https://news.cnyes.com/api/v3/news/category/tw_stock?startAt={}&endAt={}&limit=30&page={}'.format(startday,endday,p)
        res=requests.get(oth_url, headers)
#         print('正在獲取第 {} 頁 newsId'.format(p)) #########################
        # 獲取新聞的newsId
        newsIDlist=json.loads(res.text)['items']['data']
        for j in newsIDlist:        
            newsID=j['newsId']
            newsID_lt.append(newsID)
        #抓取每頁newsId的延遲時間 ?????????????????????????????????
#         time.sleep(1) ????????????????????????????????????
    
    # 由 newsId 獲取詳細新聞內容
    for k,n in enumerate(newsID_lt):    
        data=parse(headers,n,k+1,len(newsID_lt),beginday,stopday)
        #抓取每篇完整新聞的延遲時間 ???????????????????????????????
#         time.sleep(0.5) ????????????????????????????????????

def main(beginyear,beginmonth,crawlrange,stopmonth=12):
    #確認抓上半月或下半月
    if crawlrange==1:
        #抓上半個月
        for m in range(beginmonth,stopmonth+1):        
            if m < 10:
                beginday='{}-0{}-01'.format(beginyear,m)
                stopday='{}-0{}-16'.format(beginyear,m)
            else:
                beginday='{}-{}-01'.format(beginyear,m)
                stopday='{}-{}-16'.format(beginyear,m)
            crawler(beginday,stopday)
            if m ==12:
                print('程式執行完成')
                break
            # else:
                # print('切換到 {} 月份等待5秒'.format(m+1))
#             time.sleep(5) ????????????????????????????????????

    elif crawlrange==2:
        #抓下半個月
        for m in range(beginmonth,stopmonth+1):
            beginday='{}-0{}-16'.format(beginyear,m)  
            if m == 9:        
                stopday='{}-{}-01'.format(beginyear,m+1)
            elif m >= 10:
                beginday='{}-{}-16'.format(beginyear,m)
                if m == 12:
                    stopday='{}-01-01'.format(beginyear+1)
                else:
                    stopday='{}-{}-01'.format(beginyear,m+1)
            else:
                stopday='{}-0{}-01'.format(beginyear,m+1)
            
            crawler(beginday,stopday)
            if m ==stopmonth:
                print('程式執行完成')
                break
            # else:
                # print('切換到 {} 月份等待5秒'.format(m+1))
#             time.sleep(5) ????????????????????????????????????
    else:
        print('爬取區間設定錯誤!')

# %%
# beginyear=2019  #爬取新聞年份
# beginmonth=10    #爬取新聞開始月份
# stopmonth=10    #爬取停止月份
    
# #爬取月份區間,因為測試直接抓一整個月伺服器回傳的資訊可能會出現異常,
# #所以分成上半月(1~15日)和下半月(16~月底)
# for i in range(1,3):    #先爬上半月再爬下半月
#     main(beginyear,beginmonth,i,stopmonth)

# %%
cnyes_news
# Out:
# Empty DataFrame
# Columns: [date, title, content]
# Index: []

# %%
cnyes_news = pd.DataFrame(columns=['date', 'title', 'content'])

for ii in range(2015, 2016):
    print(ii)
    for jj in range(7, 13):
        for kk in range(1, 3):
            print(jj, kk)
            if ((ii==2014) & (jj==1)) & (kk==1):
                continue
            try:
                cnyes_news = pd.DataFrame(columns=['date', 'title', 'content'])
                main(ii, jj, kk, jj)
                cnyes_news = cnyes_news.drop_duplicates()
                cnyes_news = cnyes_news.reset_index(drop=True)
                cnyes_news.to_csv(str(ii) + str(jj) + str(kk) + '_cnyesnews.csv')
            except:
                print('Oh! We lost '+ str(ii) + str(jj) + str(kk))
                continue
# Out:
# 2015
# 7 1
# 總共 49 頁
# 第 100 / 1451 篇新聞:
# 第 200 / 1451 篇新聞:
# 第 300 / 1451 篇新聞:
# 第 400 / 1451 篇新聞:
# 第 500 / 1451 篇新聞:
# 第 600 / 1451 篇新聞:
# 第 700 / 1451 篇新聞:
# 第 800 / 1451 篇新聞:
# 第 900 / 1451 篇新聞:
# 第 1000 / 1451 篇新聞:
# 第 1100 / 1451 篇新聞:
# 第 1200 / 1451 篇新聞:
# 第 1300 / 1451 篇新聞:
# 第 1400 / 1451 篇新聞:
# 7 2
# 總共 56 頁
# 第 100 / 1672 篇新聞:
# 第 200 / 1672 篇新聞:
# 第 300 / 1672 篇新聞:
# 第 400 / 1672 篇新聞:
# 第 500 / 1672 篇新聞:
# 第 600 / 1672 篇新聞:
# 第 700 / 1672 篇新聞:
# 第 800 / 1672 篇新聞:
# 第 900 / 1672 篇新聞:
#
# 第 1000 / 1672 篇新聞:
# 第 1100 / 1672 篇新聞:
# 第 1200 / 1672 篇新聞:
# 第 1300 / 1672 篇新聞:
# 第 1400 / 1672 篇新聞:
# 第 1500 / 1672 篇新聞:
# 第 1600 / 1672 篇新聞:
# 程式執行完成
# 8 1
# 總共 49 頁
# 第 100 / 1460 篇新聞:
# 第 200 / 1460 篇新聞:
# 第 300 / 1460 篇新聞:
# 第 400 / 1460 篇新聞:
# 第 500 / 1460 篇新聞:
# 第 600 / 1460 篇新聞:
# 第 700 / 1460 篇新聞:
# 第 800 / 1460 篇新聞:
# 第 900 / 1460 篇新聞:
# 第 1000 / 1460 篇新聞:
# 第 1100 / 1460 篇新聞:
# 第 1200 / 1460 篇新聞:
# 第 1300 / 1460 篇新聞:
# 第 1400 / 1460 篇新聞:
# 8 2
# 總共 54 頁
# 第 100 / 1607 篇新聞:
# 第 200 / 1607 篇新聞:
# 第 300 / 1607 篇新聞:
# 第 400 / 1607 篇新聞:
# 第 500 / 1607 篇新聞:
# 第 600 / 1607 篇新聞:
# 第 700 / 1607 篇新聞:
# 第 800 / 1607 篇新聞:
# 第 900 / 1607 篇新聞:
# 第 1000 / 1607 篇新聞:
# 第 1100 / 1607 篇新聞:
# 第 1200 / 1607 篇新聞:
# 第 1300 / 1607 篇新聞:
# 第 1400 / 1607 篇新聞:
# 第 1500 / 1607 篇新聞:
# 第 1600 / 1607 篇新聞:
# 程式執行完成
# 9 1
# 總共 102 頁
# 第 100 / 3020 篇新聞:
# 第 200 / 3020 篇新聞:
# 第 300 / 3020 篇新聞:
# 第 400 / 3020 篇新聞:
# 第 500 / 3020 篇新聞:
# 第 600 / 3020 篇新聞:
# 第 700 / 3020 篇新聞:
# 第 800 / 3020 篇新聞:
# 第 900 / 3020 篇新聞:
# 第 1000 / 3020 篇新聞:
# 第 1100 / 3020 篇新聞:
# 第 1200 / 3020 篇新聞:
# 第 1300 / 3020 篇新聞:
# 第 1400 / 3020 篇新聞:
# 第 1500 / 3020 篇新聞:
# 第 1600 / 3020 篇新聞:
# 第 1700 / 3020 篇新聞:
#
# 第 1800 / 3020 篇新聞:
# 第 1900 / 3020 篇新聞:
# 第 2000 / 3020 篇新聞:
# 第 2100 / 3020 篇新聞:
# 第 2200 / 3020 篇新聞:
# 第 2300 / 3020 篇新聞:
# 第 2400 / 3020 篇新聞:
# 第 2500 / 3020 篇新聞:
# 第 2600 / 3020 篇新聞:
# 第 2700 / 3020 篇新聞:
# 第 2800 / 3020 篇新聞:
# 第 2900 / 3020 篇新聞:
# 第 3000 / 3020 篇新聞:
# 9 2
# 總共 88 頁
# 第 100 / 2635 篇新聞:
# 第 200 / 2635 篇新聞:
# 第 300 / 2635 篇新聞:
# 第 400 / 2635 篇新聞:
# 第 500 / 2635 篇新聞:
# 第 600 / 2635 篇新聞:
# 第 700 / 2635 篇新聞:
# 第 800 / 2635 篇新聞:
# 第 900 / 2635 篇新聞:
# 第 1000 / 2635 篇新聞:
# 第 1100 / 2635 篇新聞:
# 第 1200 / 2635 篇新聞:
# 第 1300 / 2635 篇新聞:
# 第 1400 / 2635 篇新聞:
# 第 1500 / 2635 篇新聞:
# 第 1600 / 2635 篇新聞:
# 第 1700 / 2635 篇新聞:
# 第 1800 / 2635 篇新聞:
# 第 1900 / 2635 篇新聞:
# 第 2000 / 2635 篇新聞:
# 第 2100 / 2635 篇新聞:
# 第 2200 / 2635 篇新聞:
# 第 2300 / 2635 篇新聞:
# 第 2400 / 2635 篇新聞:
# 第 2500 / 2635 篇新聞:
# 第 2600 / 2635 篇新聞:
# 程式執行完成
# 10 1
# 總共 94 頁
# 第 100 / 2801 篇新聞:
# 第 200 / 2801 篇新聞:
# 第 300 / 2801 篇新聞:
# 第 400 / 2801 篇新聞:
# 第 500 / 2801 篇新聞:
# 第 600 / 2801 篇新聞:
# 第 700 / 2801 篇新聞:
# 第 800 / 2801 篇新聞:
# 第 900 / 2801 篇新聞:
# 第 1000 / 2801 篇新聞:
# 第 1100 / 2801 篇新聞:
# 第 1200 / 2801 篇新聞:
# 第 1300 / 2801 篇新聞:
# 第 1400 / 2801 篇新聞:
# 第 1500 / 2801 篇新聞:
# 第 1600 / 2801 篇新聞:
# 第 1700 / 2801 篇新聞:
# 第 1800 / 2801 篇新聞:
# 第 1900 / 2801 篇新聞:
# 第 2000 / 2801 篇新聞:
# 第 2100 / 2801 篇新聞:
# 第 2200 / 2801 篇新聞:
# 第 2300 / 2801 篇新聞:
#
# 第 2400 / 2801 篇新聞:
# 第 2500 / 2801 篇新聞:
# 第 2600 / 2801 篇新聞:
# 第 2700 / 2801 篇新聞:
# 第 2800 / 2801 篇新聞:
# 10 2
# 總共 51 頁
# 第 100 / 1523 篇新聞:
# 第 200 / 1523 篇新聞:
# 第 300 / 1523 篇新聞:
# 第 400 / 1523 篇新聞:
# 第 500 / 1523 篇新聞:
# 第 600 / 1523 篇新聞:
# 第 700 / 1523 篇新聞:
# 第 800 / 1523 篇新聞:
# Oh! We lost 2015102
# 11 1
# 總共 69 頁
# 第 100 / 2062 篇新聞:
# 第 200 / 2062 篇新聞:
# 第 300 / 2062 篇新聞:
# 第 400 / 2062 篇新聞:
# 第 500 / 2062 篇新聞:
# 第 600 / 2062 篇新聞:
# 第 700 / 2062 篇新聞:
# 第 800 / 2062 篇新聞:
# 第 900 / 2062 篇新聞:
# 第 1000 / 2062 篇新聞:
# 第 1100 / 2062 篇新聞:
# 第 1200 / 2062 篇新聞:
# 第 1300 / 2062 篇新聞:
# 第 1400 / 2062 篇新聞:
# 第 1500 / 2062 篇新聞:
# 第 1600 / 2062 篇新聞:
# 第 1700 / 2062 篇新聞:
# 第 1800 / 2062 篇新聞:
# 第 1900 / 2062 篇新聞:
# 第 2000 / 2062 篇新聞:
# 11 2
# 總共 61 頁
# 第 100 / 1824 篇新聞:
# 第 200 / 1824 篇新聞:
# 第 300 / 1824 篇新聞:
# 第 400 / 1824 篇新聞:
# 第 500 / 1824 篇新聞:
# 第 600 / 1824 篇新聞:
# 第 700 / 1824 篇新聞:
# 第 800 / 1824 篇新聞:
# 第 900 / 1824 篇新聞:
# 第 1000 / 1824 篇新聞:
# 第 1100 / 1824 篇新聞:
# 第 1200 / 1824 篇新聞:
# 第 1300 / 1824 篇新聞:
# 第 1400 / 1824 篇新聞:
# 第 1500 / 1824 篇新聞:
# 第 1600 / 1824 篇新聞:
# 第 1700 / 1824 篇新聞:
# 第 1800 / 1824 篇新聞:
# 程式執行完成
# 12 1
# 總共 84 頁
# 第 100 / 2503 篇新聞:
# 第 200 / 2503 篇新聞:
# 第 300 / 2503 篇新聞:
# 第 400 / 2503 篇新聞:
# 第 500 / 2503 篇新聞:
# 第 600 / 2503 篇新聞:
# 第 700 / 2503 篇新聞:
# 第 800 / 2503 篇新聞:
# 第 900 / 2503 篇新聞:
# 第 1000 / 2503 篇新聞:
# 第 1100 / 2503 篇新聞:
# 第 1200 / 2503 篇新聞:
# 第 1300 / 2503 篇新聞:
# 第 1400 / 2503 篇新聞:
# 第 1500 / 2503 篇新聞:
# 第 1600 / 2503 篇新聞:
# 第 1700 / 2503 篇新聞:
# 第 1800 / 2503 篇新聞:
# 第 1900 / 2503 篇新聞:
# 第 2000 / 2503 篇新聞:
# 第 2100 / 2503 篇新聞:
# 第 2200 / 2503 篇新聞:
# 第 2300 / 2503 篇新聞:
# 第 2400 / 2503 篇新聞:
# 第 2500 / 2503 篇新聞:
# 程式執行完成
# 12 2
# 總共 71 頁
# 第 100 / 2128 篇新聞:
# 第 200 / 2128 篇新聞:
# 第 300 / 2128 篇新聞:
# 第 400 / 2128 篇新聞:
# 第 500 / 2128 篇新聞:
# 第 600 / 2128 篇新聞:
# 第 700 / 2128 篇新聞:
# 第 800 / 2128 篇新聞:
# 第 900 / 2128 篇新聞:
# 第 1000 / 2128 篇新聞:
# 第 1100 / 2128 篇新聞:
# 第 1200 / 2128 篇新聞:
# 第 1300 / 2128 篇新聞:
# 第 1400 / 2128 篇新聞:
# 第 1500 / 2128 篇新聞:
# 第 1600 / 2128 篇新聞:
# 第 1700 / 2128 篇新聞:
# 第 1800 / 2128 篇新聞:
# 第 1900 / 2128 篇新聞:
# 第 2000 / 2128 篇新聞:
# 第 2100 / 2128 篇新聞:
# 程式執行完成

# %%
for ii in range(2013, 2020):
    for jj in range(1, 13):
        for kk in range(1, 3):
            try:
                pd.read_csv('./'+str(ii)+str(jj)+str(kk)+'_cnyesnews.csv')
            except:
                print(ii, jj, kk)
                try:
                    cnyes_news = pd.DataFrame(columns=['date', 'title', 'content'])
                    main(ii, jj, kk, jj)
                    cnyes_news = cnyes_news.drop_duplicates()
                    cnyes_news = cnyes_news.reset_index(drop=True)
                    cnyes_news.to_csv(str(ii) + str(jj) + str(kk) + '_cnyesnews.csv')
                except:
                    print('Oh! We lost '+ str(ii) + str(jj) + str(kk))
                    continue
# Out:
# 2013 2 2
# 總共 48 頁
# 第 100 / 1436 篇新聞:
# 第 200 / 1436 篇新聞:
# 第 300 / 1436 篇新聞:
# 第 400 / 1436 篇新聞:
# 第 500 / 1436 篇新聞:
# 第 600 / 1436 篇新聞:
# 第 700 / 1436 篇新聞:
# 第 800 / 1436 篇新聞:
# 第 900 / 1436 篇新聞:
# 第 1000 / 1436 篇新聞:
# 第 1100 / 1436 篇新聞:
# 第 1200 / 1436 篇新聞:
# 第 1300 / 1436 篇新聞:
# 第 1400 / 1436 篇新聞:
# 程式執行完成
