# %%
from numpy.core.arrayprint import dtype_is_implied
import pandas as pd
import numpy as np
from pandas.core.arrays.sparse import dtype
import os

os.chdir('/Users/arthur/Desktop/factor_investment')

# %%
col_name = ['coid','stockName','date','open','high','low','close','volume_d','volume_m','return','overturn','SharesOutstanding','marketValue',
            '最後顯示買價','最後顯示賣價','log_return','marketValueRatio','成交值比重','成交筆數','本益比-TSE','本益比-TEJ','股價淨值比-TSE',
            '股價淨值比-TEJ','漲跌停','股價營收比-TEJ','股利殖利率-TSE','dividendRate','股價漲跌','高低價差比','次日開盤參考價','次日漲停價',
            '次日跌停價','注意股票','處置股票','全額交割','市場別']

# %%
df = pd.read_csv('./data/2005.csv', header=0, names=col_name,low_memory=False)
Pool=list(np.unique(df['coid'].values))

# %%
GNNStockPool=Pool

GNNStockPool.append('50')
GNNStockPool.append('56')
GNNStockPool.append('0050')
GNNStockPool.append('0056')

# %%
df[df.coid == '2721']
# Out:
#          coid stockName        date     open      high      low    close  \
# 1668493  2721   ����-KY  2009/12/17      NaN  130.7210  78.0426  92.3504
# 1669907  2721   ����-KY  2009/12/18  92.3504  104.4470  78.0426  87.7979
# 1671322  2721   ����-KY  2009/12/21  87.7979   95.6022  77.3922  78.1727
# 1672737  2721   ����-KY  2009/12/22  78.1727   91.5700  75.4412  80.6440
# 1674154  2721   ����-KY  2009/12/23  80.6440   92.8707  75.4412  75.4412
# ...       ...       ...         ...      ...       ...      ...      ...
# 6719925  2721   ����-KY  2021/04/09   6.4000    6.4300   6.3900   6.4300
# 6722152  2721   ����-KY  2021/04/12   6.4300    6.4400   6.3900   6.4400
# 6724379  2721   ����-KY  2021/04/13   6.4400    6.4400   6.4000   6.4300
# 6726606  2721   ����-KY  2021/04/14   6.4300    6.4400   6.4000   6.4300
# 6728833  2721   ����-KY  2021/04/15   6.4300    6.4600   6.4000   6.4100
#
#          volume_d  volume_m   return  ...  dividendRate   股價漲跌    高低價差比  \
# 1668493      1615    246874   0.0000  ...           NaN    NaN      NaN
# 1669907       465     68175  -4.9296  ...           NaN  -7.00  26.5672
# 1671322       419     53731 -10.9630  ...           NaN -14.80  19.1022
# 1672737       182     22561   3.1614  ...           NaN   3.80  19.3402
# 1674154       218     26632  -6.4516  ...           NaN  -8.00  21.6199
# ...           ...       ...      ...  ...           ...    ...      ...
# 6719925       587      3768   0.4687  ...           0.0   0.03   0.6240
# 6722152       612      3928   0.1555  ...           0.0   0.01   0.7788
# 6724379       539      3462  -0.1553  ...           0.0  -0.01   0.6231
# 6726606       326      2099   0.0000  ...           0.0   0.00   0.6231
# 6728833       324      2086  -0.3110  ...           0.0  -0.02   0.9346
#
#          次日開盤參考價  次日漲停價  次日跌停價  注意股票  處置股票  全額交割  市場別
# 1668493   152.82    0.0    0.0   NaN   NaN   NaN  REG
# 1669907   146.58    0.0    0.0   NaN   NaN   NaN  REG
# 1671322   128.23    0.0    0.0   NaN   NaN   NaN  REG
# 1672737   123.96    0.0    0.0   NaN   NaN   NaN  REG
# 1674154   121.77    0.0    0.0   NaN   NaN   NaN  REG
# ...          ...    ...    ...   ...   ...   ...  ...
# 6719925     6.42    0.0    0.0   NaN   NaN   NaN  REG
# 6722152     6.42    0.0    0.0   NaN   NaN   NaN  REG
# 6724379     6.42    0.0    0.0   NaN   NaN   NaN  REG
# 6726606     6.42    0.0    0.0   NaN   NaN   NaN  REG
# 6728833     6.43    0.0    0.0   NaN   NaN   NaN  REG
#
# [2785 rows x 36 columns]

# %%
AllStockMaxDate=[]
AllStockMinDate=[]
AllStock=[]
for chooseStock in list(np.unique(df['coid'].values)):
# for chooseStock in GNNStockPool:
    print(chooseStock)
    # print(np.unique(df['coid'].values))
    if str(chooseStock) not in GNNStockPool:
        continue

    stockFrame=df[df['coid']==str(chooseStock)]
    newDataFrame=pd.DataFrame()
#     print(stockFrame)
    AllDates=[]
    MaxDate='0001-01-01'
    MinDate='9999-99-99'
    for d in list(stockFrame['date'].values):
        dateString=d.replace('/','-')
        if dateString>MaxDate:
            MaxDate=dateString
        if dateString<MinDate:
            MinDate=dateString
        AllDates.append(d.replace('/','-'))
    newDataFrame['Date']=AllDates
    newDataFrame['low_adj']=stockFrame['low'].values
    newDataFrame['high_adj']=stockFrame['high'].values
    newDataFrame['open_adj']=stockFrame['open'].values
    newDataFrame['close_adj']=stockFrame['close'].values
    newDataFrame['volume']=stockFrame['volume_m'].values
    newDataFrame['marketValue']=stockFrame['marketValue'].values
   
    newDataFrame['return']=stockFrame['return'].values
    newDataFrame['stock']=str(chooseStock)
    print(newDataFrame.head(1))
    print(newDataFrame.tail(1))
    # print(AllDates)
    
    AllStockMaxDate.append(MaxDate)
    AllStockMinDate.append(MinDate)
    AllStock.append(chooseStock)
    newDataFrame.to_csv('./data/price/'+str(chooseStock)+'.csv')
# Out:
# 0050
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03  26.5352   26.7667   26.7005    26.6124  250369        41731
#
#    return stock
# 0 -0.4124  0050
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26   136.35     138.0    137.45      137.0  997127       186320
#
#       return stock
# 4108  0.6983  0050
# 0051
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2006-08-31  17.4366   18.6544   18.6281    17.4761  358810         2602
#
#    return stock
# 0  1.6462  0051
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 3698  2021-08-26     56.1      56.4      56.3      56.25    2150          591
#
#       return stock
# 3698 -0.0888  0051
# 0052
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2006-09-12   22.473   22.8091   22.8091    22.5718  102094         2312
#
#    return stock
# 0  7.0313  0052
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 3690  2021-08-26    123.4     125.5    125.15      123.9   97995         6753
#
#       return stock
# 3690  0.7727  0052
# 0053
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2007-07-16   20.793   21.0422   21.0422     20.793   45707         3529
#
#    return stock
# 0 -1.3141  0053
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 3484  2021-08-26    65.95      66.5      66.5      66.35     731          364
#
#       return stock
# 3484  0.9125  0053
# 0054
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2007-07-16  17.1428   17.2934   17.2866    17.2181  114021         3598
#
#    return stock
# 0 -0.5931  0054
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 3484  2021-08-26    31.04      31.1      31.1      31.05     155          206
#
#       return stock
# 3484 -0.0644  0054
# 0055
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2007-07-16  11.3341   11.7114    11.448     11.569  211101         1985
#
#    return stock
# 0  1.0572  0055
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 3484  2021-08-26    22.56     22.73     22.62      22.73    2929          810
#
#       return stock
# 3484  0.4863  0055
# 0056
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2007-12-26  13.3601   13.4939   13.4404    13.4672   59009         3233
#
#    return stock
# 0     0.6  0056
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 3370  2021-08-26    32.78     33.12      33.1      32.99  583530        86451
#
#       return stock
# 3370 -0.0303  0056
# 0057
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2008-02-27  28.8255    30.286   29.9785    30.1707   41730         1147
#
#    return stock
# 0  4.6667  0057
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 3332  2021-08-26    93.45      94.0      94.0       93.7    3091          424
#
#       return stock
# 3332  0.6985  0057
# 0058
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2008-02-27   26.818   27.4742   26.9492    27.4742   34090          571
#
#    return stock
# 0  4.6667  0058
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 2917  2019-12-12     48.8      49.0      48.8       49.0    1077           34
#
#       return stock
# 2917  0.4098  0058
# 0059
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2008-02-27  27.3746   29.4884   27.3746    29.4412   65155         1028
#
#    return stock
# 0     4.0  0059
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 2923  2019-12-20    49.55     49.55     49.55      49.55       0           48
#
#       return stock
# 2923     0.0  0059
# 0060
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2008-08-18   19.828   20.8793   20.3365    20.0952   39131         1309
#
#    return stock
# 0     0.0  0060
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1865  2016-02-25    26.96     27.23     26.96      27.23     621           31
#
#       return stock
# 1865  1.3398  0060
# 0061
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2009-08-17     19.1     19.73     19.73      19.15  269557         6839
#
#    return stock
# 0     0.0  0061
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 2965  2021-08-26     22.2     22.49     22.44      22.29    1457         3123
#
#       return stock
# 2965 -0.9773  0061
# 006201
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2011-01-27  11.5712   11.6179    11.579     11.579   16956         1719
#
#    return   stock
# 0  0.8808  006201
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 2597  2021-08-26     21.1      21.3     21.15      21.24    1002          264
#
#       return   stock
# 2597  0.7112  006201
# 006202
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2011-01-27    25.02     25.03     25.02      25.03  150370         1401
#
#    return   stock
# 0 -0.2789  006202
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 567  2013-05-20    25.27     25.27     25.27      25.27       0         1415
#
#      return   stock
# 567     0.0  006202
# 006203
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2011-05-12  21.8001   22.0566   21.8001    22.0053   21316          968
#
#    return   stock
# 0     0.0  006203
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 2532  2021-08-26     65.2      65.4      65.4       65.3     195          700
#
#       return   stock
# 2532  0.8494  006203
# 006204
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2011-09-28  27.6936   27.8886   27.8886     27.834   71642          821
#
#    return   stock
# 0     0.0  006204
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 2435  2021-08-26    90.45      91.0      91.0      90.45    2180          136
#
#       return   stock
# 2435  0.1661  006204
# 006205
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2011-09-26    20.16     20.51      20.5      20.45  274984         3042
#
#    return   stock
# 0     0.0  006205
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 2437  2021-08-26    35.78     36.41      36.3      35.94   32364         5278
#
#       return   stock
# 2437 -0.8278  006205
# 006206
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2012-05-11    19.55     19.81     19.81      19.66   44998         2650
#
#    return   stock
# 0    -1.7  006206
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 2283  2021-08-26    34.15      34.8      34.8      34.27    5296         1380
#
#       return   stock
# 2283 -1.3813  006206
# 006207
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2012-06-22    13.86     14.33      14.1       14.3  118603         1958
#
#    return   stock
# 0 -4.6667  006207
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 2253  2021-08-26    28.92     29.49     29.49       29.1    3134         1234
#
#       return   stock
# 2253 -1.0877  006207
# 006208
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2012-07-17   20.967   21.2574   21.0831    21.1485   60438          788
#
#    return   stock
# 0    -2.9  006208
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 2236  2021-08-26     78.4      79.4      79.2      78.75  193351        15596
#
#       return   stock
# 2236  0.5105  006208
# 00625K
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-08-08     5.63      5.66      5.65       5.66    2259            4
#
#    return   stock
# 0     0.0  00625K
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1237  2021-08-26     8.36      8.36      8.36       8.36       0            4
#
#       return   stock
# 1237  0.2398  00625K
# 00631L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2014-10-31    19.93      20.2     19.99       20.2  338333         1224
#
#    return   stock
# 0     0.0  00631L
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1669  2021-08-26    125.1    128.15     127.8     126.35  398069        15741
#
#       return   stock
# 1669  0.3973  00631L
# 00632R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2014-10-31    19.65      19.9      19.7      19.75  172054         1425
#
#    return   stock
# 0     0.0  00632R
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1669  2021-08-26     5.56      5.64      5.57       5.61  628863        58300
#
#       return   stock
# 1669 -0.1779  00632R
# 00633L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2014-11-25    21.54     21.87     21.54      21.78  411547          696
#
#    return   stock
# 0     0.0  00633L
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1652  2021-08-26    50.35      52.7      52.7       50.6  396295        10801
#
#       return   stock
# 1652  -3.619  00633L
# 00634R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2014-11-25    18.96     19.15     18.96      19.06  136165          634
#
#    return   stock
# 0     0.0  00634R
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1652  2021-08-26     4.12      4.22      4.15        4.2    1201          406
#
#       return   stock
# 1652  1.2048  00634R
# 00635U
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2015-04-15    19.79     20.03     20.02      19.84   84873         1617
#
#    return   stock
# 0     0.0  00635U
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1561  2021-08-26    23.85     23.93     23.91      23.86    4406         1766
#
#       return   stock
# 1561 -0.4174  00635U
# 00636
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2015-04-01    19.99     20.15      20.1       20.1  695115         5516
#
#    return  stock
# 0     0.5  00636
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1569  2021-08-26    23.63     24.15     24.09      23.65   27447         3343
#
#       return  stock
# 1569 -1.8265  00636
# 00636K
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-10-24     6.63      6.66      6.63       6.66       3            1
#
#    return   stock
# 0   -66.7  00636K
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 939  2021-08-26     8.47      8.47      8.47       8.47       1            1
#
#      return   stock
# 939 -1.5116  00636K
# 00637L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2015-05-18     19.9      20.8      20.0      20.72  889880         3235
#
#    return   stock
# 0     0.0  00637L
#             Date  low_adj  high_adj  open_adj  close_adj   volume  \
# 1539  2021-08-26    19.92     20.83     20.83      19.99  1025275
#
#       marketValue  return   stock
# 1539        23510 -3.6162  00637L
# 00638R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2015-05-18    19.85      20.1     19.85      20.03  385408          460
#
#    return   stock
# 0     0.0  00638R
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1539  2021-08-26     8.55      8.72      8.55       8.69    8054          447
#
#       return   stock
# 1539  1.6374  00638R
# 00639
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2015-06-09    15.77     16.08      16.0      15.82  901728         2814
#
#    return  stock
# 0     0.0  00639
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1523  2021-08-26    16.11     16.45     16.45      16.16   12403         1913
#
#       return  stock
# 1523 -1.3431  00639
# 00640L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2015-09-10    18.96     19.63     19.63      19.52  704089          740
#
#    return   stock
# 0     0.0  00640L
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1458  2021-08-26    27.89     28.09     27.93      28.06    7792          292
#
#       return   stock
# 1458     0.0  00640L
# 00641R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2015-09-10    20.19     20.53     20.19      20.26  473947          542
#
#    return   stock
# 0     0.0  00641R
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1458  2021-08-26    10.59     10.63     10.61       10.6    1325          278
#
#       return   stock
# 1458     0.0  00641R
# 00642U
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2015-09-07    19.62     19.82     19.67      19.73   57647          529
#
#    return   stock
# 0     0.0  00642U
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1461  2021-08-26    11.72     11.77     11.76      11.72   75717        10130
#
#       return   stock
# 1461  0.6873  00642U
# 00643
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2015-12-02     19.0     19.25     19.18       19.1  296768         2869
#
#    return  stock
# 0     0.0  00643
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1402  2021-08-26    18.37     18.61     18.61      18.42   10477         1650
#
#       return  stock
# 1402 -0.7543  00643
# 00643K
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-08-26     3.26      3.26      3.26       3.26     326            2
#
#    return   stock
# 0     0.0  00643K
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1223  2021-08-26     4.36      4.36      4.36       4.36       0            1
#
#       return   stock
# 1223     0.0  00643K
# 00645
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2015-11-06    19.97     20.08      20.0      20.08  265414          703
#
#    return  stock
# 0     0.0  00645
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1420  2021-08-26    25.23     25.34     25.28      25.32    3345          430
#
#       return  stock
# 1420  0.0791  00645
# 00646
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2015-12-14     19.0     19.64     19.44      19.61   74995         1245
#
#    return  stock
# 0     0.0  00646
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1394  2021-08-26    38.37     38.46     38.39      38.46   11965         6172
#
#       return  stock
# 1394  0.1823  00646
# 00647L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2015-12-14     19.1     19.37     19.25      19.32   13426          481
#
#    return   stock
# 0     0.0  00647L
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1394  2021-08-26     70.9      71.1      71.0       71.1    1780          385
#
#       return   stock
# 1394  0.2821  00647L
# 00648R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2015-12-14    20.06     20.39     20.06      20.33  120255          787
#
#    return   stock
# 0     0.0  00648R
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1394  2021-08-26     6.82      6.84      6.83       6.83   16742         1285
#
#       return   stock
# 1394 -0.1462  00648R
# 00649
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-01-27    14.38     14.89     14.38      14.72  164623         1402
#
#    return  stock
# 0     0.0  00649
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 959  2019-12-27    20.82      21.1     20.82      21.05    4536           89
#
#      return  stock
# 959  1.3969  00649
# 00650L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-01-27    14.25     14.89     14.35      14.57   71937          493
#
#    return   stock
# 0     0.0  00650L
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1363  2021-08-26    23.55     24.27     24.21      23.66   29987          363
#
#       return   stock
# 1363 -2.2718  00650L
# 00651R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-01-27    14.83     15.24      14.9      15.14  155996          752
#
#    return   stock
# 0     0.0  00651R
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1363  2021-08-26      7.5      7.65      7.59       7.62    5439          207
#
#       return   stock
# 1363   1.061  00651R
# 00652
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-03-29    19.49     19.74     19.69      19.49  119936          897
#
#    return  stock
# 0     0.0  00652
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1326  2021-08-26     27.6     27.75     27.68      27.61    9947          484
#
#       return  stock
# 1326 -0.1808  00652
# 00653L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-03-29    19.46     19.86     19.86      19.46   80496          679
#
#    return   stock
# 0     0.0  00653L
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1326  2021-08-26    42.02     42.37     42.17      42.37    8449          631
#
#       return   stock
# 1326 -0.4464  00653L
# 00654R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-03-29    19.88     20.02     19.92      20.02  188530          830
#
#    return   stock
# 0     0.0  00654R
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1326  2021-08-26     8.67      8.71      8.71       8.68    1241          199
#
#       return   stock
# 1326  0.2309  00654R
# 00655L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-03-18    19.97      20.6     20.01      20.39  410766         1172
#
#    return   stock
# 0     0.0  00655L
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1333  2021-08-26     37.7     39.44     39.44      37.87   95703         4940
#
#       return   stock
# 1333 -3.7856  00655L
# 00656R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-03-18    19.45     19.76     19.69      19.56  161920          721
#
#    return   stock
# 0     0.0  00656R
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1333  2021-08-26      7.8      7.98      7.82       7.95    1582          198
#
#       return   stock
# 1333  1.5326  00656R
# 00657
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-05-09     19.5     19.86      19.5      19.85  111160          697
#
#    return  stock
# 0     0.0  00657
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1300  2021-08-26     33.8     33.83      33.8      33.83    3623          146
#
#       return  stock
# 1300  0.0888  00657
# 00657K
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-10-24     8.67      8.69      8.67       8.69       2            1
#
#    return   stock
# 0  -56.55  00657K
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 939  2021-08-26     12.1      12.1      12.1       12.1       2            0
#
#      return   stock
# 939  0.1656  00657K
# 00658L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-05-09    20.05     20.46     20.06      20.43  161050          548
#
#    return   stock
# 0     0.0  00658L
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 914  2020-02-03    37.64     37.64     37.64      37.64       0           31
#
#      return   stock
# 914  1.7297  00658L
# 00659R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-05-09    19.63     19.74     19.67      19.68   89648          532
#
#    return   stock
# 0     0.0  00659R
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 914  2020-02-03     11.2      11.3     11.28      11.21    1864           34
#
#      return   stock
# 914   0.991  00659R
# 00660
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-06-15  18.4949   18.6287   18.4949    18.5809   34949          341
#
#    return  stock
# 0     0.0  00660
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1274  2021-08-26    29.81     29.85     29.85      29.81     126          269
#
#       return  stock
# 1274  0.0671  00660
# 00661
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-06-15    19.88     20.09      19.9      20.03  148605          619
#
#    return  stock
# 0     0.0  00661
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1274  2021-08-26    34.59      34.6     34.59       34.6     103          205
#
#       return  stock
# 1274     0.0  00661
# 00662
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-06-17     19.9     19.97     19.93      19.97   46009          620
#
#    return  stock
# 0     0.0  00662
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1272  2021-08-26     55.0      55.2      55.2      55.05   14460         2369
#
#       return  stock
# 1272 -0.2717  00662
# 00663L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-07-14    19.89     20.15     19.91      20.04  148318          387
#
#    return   stock
# 0     0.0  00663L
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1254  2021-08-26   112.75     115.5     115.3     114.15    3857         5572
#
#       return   stock
# 1254  0.2635  00663L
# 00664R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-07-14     19.9     20.05     20.02      19.95  134927          610
#
#    return   stock
# 0     0.0  00664R
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1254  2021-08-26      6.3      6.38       6.3       6.36   45967         3231
#
#       return   stock
# 1254  -0.157  00664R
# 00665L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-08-05    20.03     20.57     20.04      20.42  112595          591
#
#    return   stock
# 0     0.0  00665L
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1238  2021-08-26    16.88      17.5     17.44      16.95    3097          313
#
#       return   stock
# 1238 -2.7539  00665L
# 00666R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-08-05    19.54      19.8      19.8      19.58   55672          423
#
#    return   stock
# 0     0.0  00666R
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1238  2021-08-26    12.67      12.7      12.7      12.67     901          122
#
#       return   stock
# 1238  0.3962  00666R
# 00667
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-10-07    19.73     19.81      19.8      19.73   39396          284
#
#    return  stock
# 0     0.0  00667
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 543  2018-12-18    19.94     20.05     20.02      19.94     440           18
#
#      return  stock
# 543 -1.0422  00667
# 00668
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-10-17    19.64     19.87     19.64      19.85   65508          626
#
#    return  stock
# 0     0.0  00668
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1191  2021-08-26    35.75     35.87     35.87      35.75     252          853
#
#       return  stock
# 1191 -0.0559  00668
# 00668K
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-10-24     8.15      8.16      8.15       8.16       1            1
#
#    return   stock
# 0   -59.2  00668K
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 939  2021-08-26     12.8      12.8      12.8       12.8       2            0
#
#      return   stock
# 939  0.2349  00668K
# 00669R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-10-17    19.87     19.97     19.87      19.93   89486          570
#
#    return   stock
# 0     0.0  00669R
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1191  2021-08-26      7.8      7.82       7.8       7.82   15116         2273
#
#       return   stock
# 1191   0.128  00669R
# 00670L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-02-21    20.17     20.25      20.2      20.21  182898          407
#
#    return   stock
# 0     0.0  00670L
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1106  2021-08-26    112.5    112.95    112.95      112.7   20972         1312
#
#       return   stock
# 1106 -0.3537  00670L
# 00671R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-02-21    19.74     19.79     19.78      19.76  151356          581
#
#    return   stock
# 0     0.0  00671R
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1106  2021-08-26     5.24      5.26      5.25       5.25   19564         1378
#
#       return   stock
# 1106  0.1908  00671R
# 00672L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-10-07    20.29     20.49     20.29      20.45  175895          709
#
#    return   stock
# 0     0.0  00672L
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1004  2020-11-12     0.75      0.76      0.75       0.75  162657         1527
#
#       return   stock
# 1004     0.0  00672L
# 00673R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-10-07    19.61     19.76     19.61      19.69   46296          605
#
#    return   stock
# 0     0.0  00673R
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1196  2021-08-26    15.87     15.94     15.89      15.94   18093          434
#
#       return   stock
# 1196 -0.6854  00673R
# 00674R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-10-07     20.0     20.15      20.0      20.13   38832          274
#
#    return   stock
# 0     0.0  00674R
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1196  2021-08-26    13.24     13.29     13.26      13.29    1154          267
#
#       return   stock
# 1196  0.4535  00674R
# 00675L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-10-05     9.94     10.05      9.98       9.98  132596          537
#
#    return   stock
# 0     0.0  00675L
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1198  2021-08-26    48.54     49.73     49.72      49.04   45656         5752
#
#       return   stock
# 1198  0.2043  00675L
# 00676R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-10-05     9.97     10.03     10.01       10.0  166984          690
#
#    return   stock
# 0     0.0  00676R
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1198  2021-08-26     3.44      3.48      3.45       3.46   26060         2375
#
#       return   stock
# 1198 -0.2882  00676R
# 00677U
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2016-12-30    19.93     20.02     19.99      19.93   76647          652
#
#    return   stock
# 0     0.0  00677U
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1077  2021-06-02     1.48      1.49      1.48       1.48  402175         2200
#
#       return   stock
# 1077  0.6803  00677U
# 00678
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-01-16    19.55     19.77     19.55      19.57   66927          938
#
#    return  stock
# 0     0.0  00678
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1127  2021-08-26    30.32     30.45     30.32      30.43   12453          242
#
#       return  stock
# 1127  0.3297  00678
# 00679B
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-01-17  35.6746   35.9184   35.8462    35.8372   36832        10208
#
#    return   stock
# 0     0.0  00679B
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1126  2021-08-26    41.81     41.91      41.9      41.89   15342         9852
#
#       return   stock
# 1126 -0.6404  00679B
# 00680L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-01-17    19.85     20.05     19.88      20.05   22400          252
#
#    return   stock
# 0     0.0  00680L
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1126  2021-08-26    25.45     25.53     25.49      25.53     485          117
#
#       return   stock
# 1126 -1.2379  00680L
# 00681R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-01-17    19.64     19.88     19.64       19.8   34124          249
#
#    return   stock
# 0     0.0  00681R
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1126  2021-08-26    13.21     13.22     13.21      13.22     304        13175
#
#       return   stock
# 1126  0.6855  00681R
# 00682U
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-03-14     19.9     19.95     19.95       19.9   30757          202
#
#    return   stock
# 0     0.0  00682U
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1093  2021-08-26    18.37     18.38     18.38      18.37     570          434
#
#       return   stock
# 1093  -0.163  00682U
# 00683L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-03-14    19.93      20.0      20.0      19.98   47612          218
#
#    return   stock
# 0     0.0  00683L
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1093  2021-08-26    17.41     17.46     17.45      17.45   12680          976
#
#       return   stock
# 1093 -0.1716  00683L
# 00684R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-03-14    19.87     19.92     19.92      19.87   18847          222
#
#    return   stock
# 0     0.0  00684R
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1093  2021-08-26    18.56     18.56     18.56      18.56      18           78
#
#       return   stock
# 1093 -0.4826  00684R
# 00685L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-03-30     9.91      10.0      9.94       9.92   20033          264
#
#    return   stock
# 0     0.0  00685L
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1081  2021-08-26    42.72     43.19     43.19      43.08     644          157
#
#       return   stock
# 1081  0.8191  00685L
# 00686R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-03-30     9.95      10.0      9.97       9.97   26874          357
#
#    return   stock
# 0     0.0  00686R
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1081  2021-08-26     3.75       3.8      3.76       3.78    1655          124
#
#       return   stock
# 1081     0.0  00686R
# 00687B
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-04-13  36.6028   36.7397   36.6119    36.6758   59601          594
#
#    return   stock
# 0     0.0  00687B
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1073  2021-08-26    43.73      43.9     43.73       43.9    2735         8485
#
#       return   stock
# 1073 -0.5437  00687B
# 00688L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-04-13     20.3     20.55     20.36      20.55   49599          228
#
#    return   stock
# 0     0.0  00688L
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1073  2021-08-26    25.34     25.45      25.4      25.45    3128          117
#
#       return   stock
# 1073 -1.2801  00688L
# 00689R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-04-13    19.43     19.54     19.53      19.53   33413          203
#
#    return   stock
# 0     0.0  00689R
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1073  2021-08-26    13.84     13.87     13.87      13.84    4916         6538
#
#       return   stock
# 1073  0.4354  00689R
# 00690
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-03-31   17.168   17.2542   17.2111    17.1766   57660          435
#
#    return  stock
# 0     0.0  00690
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1080  2021-08-26    32.47     32.76     32.76      32.56    3768          369
#
#       return  stock
# 1080  0.1846  00690
# 00691R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-03-31    19.82     19.94     19.88      19.94   34950          251
#
#    return   stock
# 0     0.0  00691R
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 895  2020-11-23    10.42     10.46     10.42      10.46     239           22
#
#      return   stock
# 895 -1.3208  00691R
# 00692
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-05-17  16.7808   16.8909   16.7892    16.7977  278570         3246
#
#    return  stock
# 0     0.0  00692
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1050  2021-08-26    35.06     35.48     35.39      35.24  129164        11463
#
#       return  stock
# 1050  0.4275  00692
# 00693U
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-04-25     20.0     20.04     20.03      20.02   86768          544
#
#    return   stock
# 0     0.0  00693U
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1065  2021-08-26    21.45      21.5      21.5      21.48    2598          874
#
#       return   stock
# 1065  0.1866  00693U
# 00694B
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-06-08  37.3444   37.4195   37.4195    37.3444   62251          202
#
#    return   stock
# 0     0.0  00694B
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1035  2021-08-26    37.21     37.33     37.29      37.33    4473         6162
#
#       return   stock
# 1035  0.1073  00694B
# 00695B
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-06-08  35.3556   35.4355   35.4355    35.3556   60512          206
#
#    return   stock
# 0     0.0  00695B
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1035  2021-08-26    37.43     37.49     37.43      37.49    4496          457
#
#       return   stock
# 1035 -0.1598  00695B
# 00696B
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-06-08  36.2512   36.3331   36.3331    36.2512   61453          206
#
#    return   stock
# 0     0.0  00696B
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1035  2021-08-26    43.51     43.72     43.63      43.69    8457        27751
#
#       return   stock
# 1035 -0.6142  00696B
# 00697B
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-06-23  37.5894   37.9018   37.6367    37.8829   67624          589
#
#    return   stock
# 0     0.0  00697B
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1024  2021-08-26    39.75     39.82      39.8      39.82    9961          327
#
#       return   stock
# 1024 -0.2505  00697B
# 00698L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-06-23    19.81     19.87     19.82      19.83   37239          221
#
#    return   stock
# 0     0.0  00698L
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 271  2018-07-27     17.6      17.6      17.6       17.6       0           20
#
#      return   stock
# 271     0.0  00698L
# 00699R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-06-23    19.79     19.88     19.83      19.83   49781          212
#
#    return   stock
# 0     0.0  00699R
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 277  2018-08-06    20.38     20.38     20.38      20.38       0           14
#
#      return   stock
# 277  0.0491  00699R
# 00700
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-07-28    19.52      19.8      19.8      19.53   36644          312
#
#    return  stock
# 0     0.0  00700
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 999  2021-08-26    16.14      16.7      16.6      16.16    3321          113
#
#      return  stock
# 999 -2.5332  00700
# 00701
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-08-17  17.2628   17.4189   17.2888    17.4189  273385          932
#
#    return  stock
# 0     0.0  00701
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 985  2021-08-26     24.6     24.71     24.71      24.71   21863         3741
#
#      return  stock
# 985   0.081  00701
# 00702
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-08-17  17.8918   17.9456   17.9187    17.9366  116605          484
#
#    return  stock
# 0     0.0  00702
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 985  2021-08-26    20.15     20.17     20.15      20.16    2136          155
#
#      return  stock
# 985  0.0496  00702
# 00703
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-08-10    19.67     19.93     19.88      19.74   11835          534
#
#    return  stock
# 0     0.0  00703
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 990  2021-08-26    20.86     21.24     21.24      20.86    1235          168
#
#      return  stock
# 990 -1.7891  00703
# 00704L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-08-10    19.45     19.95     19.94      19.51   41642          231
#
#    return   stock
# 0     0.0  00704L
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 324  2018-11-29    18.71     18.71     18.71      18.71      18           25
#
#      return   stock
# 324  2.8022  00704L
# 00705R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-08-10     19.5     20.15      19.9      20.09   87961          227
#
#    return   stock
# 0     0.0  00705R
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 321  2018-11-26     19.2     19.22     19.22       19.2      38           34
#
#      return   stock
# 321 -1.0309  00705R
# 00706L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-09-01    19.97     20.02     20.02      20.01   63473          192
#
#    return   stock
# 0     0.0  00706L
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 974  2021-08-26    15.93     15.93     15.93      15.93       0          105
#
#      return   stock
# 974     0.0  00706L
# 00707R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-09-01    19.82      19.9      19.9      19.85   60460          196
#
#    return   stock
# 0     0.0  00707R
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 974  2021-08-26    19.73     19.73     19.73      19.73       0           86
#
#      return   stock
# 974 -0.0507  00707R
# 00708L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-09-01    20.18     20.29     20.23      20.29   83359          204
#
#    return   stock
# 0     0.0  00708L
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 974  2021-08-26    25.86     25.97     25.97      25.89   16809         2008
#
#      return   stock
# 974 -0.9185  00708L
# 00709
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-08-15    19.99     20.03      20.0      20.02    1800          340
#
#    return  stock
# 0     0.0  00709
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 987  2021-08-26     24.1     24.13      24.1      24.12    3286          204
#
#      return  stock
# 987 -0.3306  00709
# 00710B
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-08-22  16.5406   16.6233   16.5571     16.582    1824          567
#
#    return   stock
# 0     0.0  00710B
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 982  2021-08-26    18.27      18.3     18.28       18.3    3836         5742
#
#      return   stock
# 982  0.1094  00710B
# 00711B
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-08-22   17.177   17.2454   17.1855    17.2454    1730          570
#
#    return   stock
# 0     0.0  00711B
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 982  2021-08-26    20.61     20.69     20.69      20.61    2514        15174
#
#      return   stock
# 982 -0.3385  00711B
# 00712
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-08-22  15.1175   15.1778   15.1251    15.1552    1768          362
#
#    return  stock
# 0     0.0  00712
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 982  2021-08-26    14.28     14.31      14.3      14.29   27493         4530
#
#      return  stock
# 982  0.1402  00712
# 00713
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-09-27  25.5325   25.7303   25.5325    25.6873   20368         2316
#
#    return  stock
# 0    -0.4  00713
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 956  2021-08-26    43.18      43.5      43.5      43.35    3313         3490
#
#      return  stock
# 956 -0.3448  00713
# 00714
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-10-27  17.4132   17.5992   17.5726    17.5992   51560          210
#
#    return  stock
# 0   -0.65  00714
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 936  2021-08-26    22.24      22.3     22.29      22.27    5221          113
#
#      return  stock
# 936 -0.3579  00714
# 00715L
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-11-16    19.72     19.82     19.72       19.8   13038          295
#
#    return   stock
# 0    -1.0  00715L
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 922  2021-08-26     8.16      8.23      8.22       8.17  448692         8373
#
#      return   stock
# 922  1.8703  00715L
# 00716R
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-11-16    19.98     20.04     20.03      19.99   15882          213
#
#    return   stock
# 0   -0.05  00716R
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 421  2019-08-07    16.44      16.5     16.44      16.49      98            2
#
#      return   stock
# 421  1.4145  00716R
# 00717
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-11-29  16.9976   17.0488   16.9976    17.0402   97579         3537
#
#    return  stock
# 0   -0.15  00717
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 913  2021-08-26    16.93     16.97     16.93      16.95   12461         4544
#
#      return  stock
# 913  0.1181  00717
# 00718B
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2018-02-08   17.383   17.4968   17.4968     17.383   36741         4846
#
#    return   stock
# 0    -0.7  00718B
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 863  2021-08-26    19.49     19.55     19.49      19.52    4506        22624
#
#      return   stock
# 863  0.1539  00718B
# 00719B
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2018-02-01  28.3548   29.2348    29.225    29.1468   30057          209
#
#    return   stock
# 0 -0.6333  00719B
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 868  2021-08-26    29.99     29.99     29.99      29.99    2999        18489
#
#      return   stock
# 868 -0.1664  00719B
# 00720B
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2018-02-01  35.2435   35.4127   35.3949    35.2791   25391          202
#
#    return   stock
# 0  -0.975  00720B
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 868  2021-08-26    44.36     44.52     44.51      44.45    6676        32831
#
#      return   stock
# 868 -0.6038  00720B
# 00721B
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2018-02-01  40.5463    40.726   40.5463    40.7171   49092         2362
#
#    return   stock
# 0  0.6889  00721B
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 868  2021-08-26    44.72     44.81     44.81      44.72    8342        18139
#
#      return   stock
# 868     0.0  00721B
# 00722B
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-12-15   34.989   35.2086   34.9978    35.2086   25653          370
#
#    return   stock
# 0     0.2  00722B
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 901  2021-08-26    47.57     47.71     47.62      47.71    5440        47507
#
#      return   stock
# 901 -0.3134  00722B
# 00723B
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2017-12-15  35.7968   35.9583   35.8416    35.8865   34273          263
#
#    return   stock
# 0     0.0  00723B
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 901  2021-08-26    42.79     42.87     42.79      42.87    4501        36893
#
#      return   stock
# 901 -0.5106  00723B
# 00724B
# ...
#
#    return stock
# 0     0.0  9917
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     97.7      99.5      98.9       99.5   52332        44894
#
#       return stock
# 4108  0.1006  9917
# 9918
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03   8.1746    8.2691    8.1746     8.2691     121         2821
#
#    return stock
# 0     0.0  9918
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     41.3      41.4      41.4       41.3    3001         7456
#
#       return stock
# 4108     0.0  9918
# 9919
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03   8.1858    8.3529    8.2693     8.2972   13292         2835
#
#    return stock
# 0  1.3605  9919
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     22.7      23.0     22.95      22.75   13201         4445
#
#       return stock
# 4108 -0.8715  9919
# 9921
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03  24.1615   24.3832   24.3832    24.3832    9341        15410
#
#    return stock
# 0  0.9174  9921
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26    308.5     316.5     309.5      314.0  267525       117770
#
#       return stock
# 4108   0.641  9921
# 9922
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03     0.81      0.88      0.86       0.87      89          250
#
#    return stock
# 0  2.3529  9922
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 1353  2010-06-18     0.17      0.19      0.19       0.19     191           54
#
#       return stock
# 1353  5.5556  9922
# 9924
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03  10.9616   11.0575   10.9616    10.9936    2304         6448
#
#    return stock
# 0  -0.578  9924
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26    40.35      40.8     40.35       40.6    3399         7651
#
#       return stock
# 4108  0.2469  9924
# 9925
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03   6.2434    6.4239    6.3156     6.2795   33936         5978
#
#    return stock
# 0   0.578  9925
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26    37.75     37.85     37.85      37.75    5581        14628
#
#       return stock
# 4108 -0.2642  9925
# 9926
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03   4.5438    4.5948    4.5438     4.5948     578         1596
#
#    return stock
# 0  0.7463  9926
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26    46.85     47.15     47.15      46.85     515         8410
#
#       return stock
# 4108 -1.2645  9926
# 9927
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03   9.0055    9.2162    9.1109     9.1635   79477         5221
#
#    return stock
# 0  1.7544  9927
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26    34.35      35.5      35.0       34.9   27314         7299
#
#       return stock
# 4108  1.7493  9927
# 9928
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03  72.1721   74.4376   74.4376    73.4667   11258         4133
#
#    return stock
# 0 -0.8734  9928
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     5.34      5.41      5.34       5.41     191          815
#
#       return stock
# 4108  1.6917  9928
# 9929
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03   9.4316    9.7746    9.4316     9.6031    3425          835
#
#    return stock
# 0  1.8182  9929
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     9.75       9.8       9.8        9.8     171          993
#
#       return stock
# 4108  0.5128  9929
# 9930
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03   6.7756    6.9268    6.8058     6.8663   14218         4410
#
#    return stock
# 0 -1.3043  9930
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     44.5      45.2      44.9      45.15    9149        11222
#
#       return stock
# 4108   1.726  9930
# 9931
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03   4.5761    4.5761    4.5761     4.5761       0         1022
#
#    return stock
# 0     0.0  9931
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     38.2      38.4     38.35       38.2     383         4218
#
#       return stock
# 4108 -1.1643  9931
# 9933
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03   7.3388    7.5223    7.4122     7.3388   28187        11608
#
#    return stock
# 0 -0.9901  9933
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     35.7     35.95      35.9      35.75   31168        27308
#
#       return stock
# 4108 -0.5563  9933
# 9934
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03  11.9098   12.0698   12.0378    12.0058    4469         7337
#
#    return stock
# 0 -1.0554  9934
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     15.6     15.85     15.85       15.7    3327         5623
#
#       return stock
# 4108 -0.3175  9934
# 9935
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03  17.3428   17.6742   17.3428    17.4532    7115         1864
#
#    return stock
# 0  0.6369  9935
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     20.1      20.4      20.4      20.25    1994         3435
#
#       return stock
# 4108  0.2475  9935
# 9936
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03     3.18       3.3      3.19       3.27    2149          425
#
#    return stock
# 0  2.5078  9936
#           Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 81  2005-05-09      0.2       0.2       0.2        0.2      48           26
#
#     return stock
# 81 -4.7619  9936
# 9937
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03    9.541    9.9095    9.5819     9.9095   95356         7478
#
#    return stock
# 0  3.4188  9937
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26    48.85     49.35      49.2      49.35    3593        15251
#
#       return stock
# 4108  0.3049  9937
# 9938
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03   7.6342    7.9812    7.8077     7.9812   23564         3685
#
#    return stock
# 0  3.6036  9938
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     82.0      83.2      82.9       83.0   33163        24731
#
#       return stock
# 4108  0.3628  9938
# 9939
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03  10.8685   11.0957   10.8685    10.9821   11676         4541
#
#    return stock
# 0  1.0453  9939
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     74.4      75.4      75.4       75.0   49623        21584
#
#       return stock
# 4108     0.0  9939
# 9940
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03   6.8731    7.3137    6.8731     7.3137   41921        10111
#
#    return stock
# 0  6.4103  9940
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     30.2      30.8      30.8      30.25    7373        22290
#
#       return stock
# 4108 -1.1438  9940
# 9941
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03   8.5101    8.6514    8.5384     8.5949   12773         7168
#
#    return stock
# 0  0.9967  9941
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26    163.5     170.5     166.5      170.0  256849        64965
#
#       return stock
# 4108  3.0303  9941
# 9942
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03  13.8696   14.0328   13.9675    13.9349    8936         2796
#
#    return stock
# 0 -0.2336  9942
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     87.1      88.2      87.9       87.5   19326         7277
#
#       return stock
# 4108  0.2291  9942
# 9943
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03  10.8976   11.7048   10.8976    11.4021    8080         4161
#
#    return stock
# 0 -2.5862  9943
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     61.4      62.4      61.4       62.4   15410         9193
#
#       return stock
# 4108  1.7945  9943
# 9944
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03  11.2965   11.4041   11.4041    11.3503    3421         1633
#
#    return stock
# 0 -0.4717  9944
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     20.2     20.35     20.25       20.2    1516         2204
#
#       return stock
# 4108     0.0  9944
# 9945
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03   3.1601    3.3287    3.1601     3.3287  228786         6186
#
#    return stock
# 0  6.7568  9945
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     65.1      65.7      65.7       65.3  173883        98269
#
#       return stock
# 4108 -0.1529  9945
# 9946
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-03-22   4.9013    4.9013    4.9013     4.9013     669          343
#
#    return stock
# 0  6.9853  9946
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4059  2021-08-26    16.35      16.8      16.5      16.75    4855         5209
#
#       return stock
# 4059  1.5152  9946
# 9947
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03    15.05     15.05     15.05      15.05       0          752
#
#    return stock
# 0     0.0  9947
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 159  2005-08-29     9.96      9.96      9.96       9.96       0          498
#
#      return stock
# 159     0.0  9947
# 9949
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03  10.4022   10.4022   10.4022    10.4022      67          596
#
#    return stock
# 0 -2.5974  9949
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     10.6      10.7      10.7       10.7     332          503
#
#       return stock
# 4108     0.0  9949
# 9950
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03   4.8733    4.9581    4.9581     4.8733      92          511
#
#    return stock
# 0     0.0  9950
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     7.65       8.0       7.8        7.9     804         1167
#
#       return stock
# 4108 -4.7045  9950
# 9951
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03  16.1825   16.3623   16.3623    16.3623    3792         1638
#
#    return stock
# 0 -0.4376  9951
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4088  2021-08-26     84.7      86.5      86.5       85.1   23832         6374
#
#       return stock
# 4088 -0.5841  9951
# 9953
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03    11.75      12.5      17.5       12.0     525         3984
#
#     return stock
# 0 -31.4286  9953
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 604  2007-06-15     7.17       9.5      10.2       7.17     868         3184
#
#       return stock
# 604 -29.7059  9953
# 9955
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03  14.7728   14.9794   14.8761    14.9277    5969         1273
#
#    return stock
# 0  0.3472  9955
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     17.2      17.4      17.4       17.3     884         1786
#
#       return stock
# 4108  0.2899  9955
# 9956
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03     38.2      38.2      38.2       38.2       0         4394
#
#    return stock
# 0     0.0  9956
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 168  2005-09-12     35.1      35.1      35.0       35.1     210         4037
#
#      return stock
# 168  0.2857  9956
# 9957
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03   6.6874    6.8669     6.822     6.7772    3523        20928
#
#    return stock
# 0 -0.6579  9957
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26    13.65      17.1      13.6      15.65  160623        41009
#
#        return stock
# 4108  15.0735  9957
# 9958
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2008-03-12  10.5284   13.7527   10.5284    13.7527  114050         1858
#
#     return stock
# 0  54.8148  9958
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 3323  2021-08-26    113.5     119.5     115.0      115.0  348150        26638
#
#       return stock
# 3323  0.4367  9958
# 9960
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03   7.6402    7.7876    7.7139     7.7631    1128          371
#
#    return stock
# 0 -0.9404  9960
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 4108  2021-08-26     26.7      26.9      26.9       26.8      81          900
#
#       return stock
# 4108 -0.3717  9960
# 9961
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2005-01-03   4.6041    4.6918    4.6041     4.6041      21          359
#
#    return stock
# 0     0.0  9961
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 2798  2016-04-22     0.61      0.85      0.84       0.75     197           51
#
#        return stock
# 2798 -10.7143  9961
# 9962
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2006-07-10   5.1642    6.5833    5.7555     6.2876   24595          899
#
#     return stock
# 0  51.9048  9962
#             Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 3736  2021-08-26     19.7     21.55      20.1      21.55  290385         1944
#
#       return stock
# 3736   9.949  9962
# 9965
#          Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 0  2006-12-29   9.0153    9.0153       NaN     9.0153      10         1220
#
#    return stock
# 0     0.0  9965
#            Date  low_adj  high_adj  open_adj  close_adj  volume  marketValue  \
# 575  2009-04-30     2.96       3.0      2.97        3.0       5          366
#
#      return stock
# 575  1.0101  9965
