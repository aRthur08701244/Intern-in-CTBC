# %% [markdown]
# # EmbeddingLayer.py

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon Mar 20 23:41:51 2017

@author: red-sky
"""


import numpy as np
import theano
from theano import tensor as T


class EmbeddingLayer(object):
    def __init__(self, num_vocab, word_dim, rng, embedding_w=None):
        '''
        word_dim :: dimension of the word embeddings
        num_vocab :: number of word embeddings in the vocabulary
        embedding_w :: pre-train word vector
        '''

        if embedding_w is None:
            word_vectors = rng.uniform(-1.0, 1.0, (num_vocab, word_dim))
            self.embedding_w = theano.shared(word_vectors,
                                             name="EmbeddingLayer_W") \
                .astype(theano.config.floatX)
        else:
            self.embedding_w = theano.shared(embedding_w,
                                             name="EmbeddingLayer_W") \
                .astype(theano.config.floatX)

        self.params = [self.embedding_w]
        self.infor = [num_vocab, word_dim]

    def words_ind_2vec(self, index):
        map_word_vectors = self.embedding_w[index]
        output = T.mean(map_word_vectors,  axis=0)
        return output, map_word_vectors


if __name__ == "__main__":
    rng = np.random.RandomState(220495)
    arrWords = T.ivector("words")
    EMBD = EmbeddingLayer(100, 150, rng=rng)
    Word2Vec = theano.function(
        inputs=[arrWords],
        outputs=EMBD.words_ind_2vec(arrWords)
    )
    Vec = Word2Vec([1, 2, 3, 4])
    Vec = Word2Vec([2, 3, 4])
    print("Dim: ", Vec.shape)
    print("Val: ", Vec)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [2], in <cell line: 42>()
#      50 Vec = Word2Vec([1, 2, 3, 4])
#      51 Vec = Word2Vec([2, 3, 4])
# ---> 52 print("Dim: ", Vec.shape)
#      53 print("Val: ", Vec)
#
# AttributeError: 'list' object has no attribute 'shape'

# %% [markdown]
# # EventEmbedding.py

# %%
import sys
import json
import theano
import pickle
import os.path
import numpy as np
import theano.tensor as T
from SmallUtils import createShareVar, ADAM_OPTIMIZER
from EmbeddingLayer import EmbeddingLayer
from RoleDependentLayer import RoleDependentLayer

# %% [markdown]
# 更改過num_K: 150 -> 80
#
# word_dim?? -> 100
#
# 更改all_index
#
# 修改ob1_real fake, act, obj2的datatype

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sat Mar 25 17:36:33 2017

@author: red-sky
"""
import sys
import json
import theano
import pickle
import os.path
import numpy as np
import theano.tensor as T
from SmallUtils import createShareVar, ADAM_OPTIMIZER
from EmbeddingLayer import EmbeddingLayer
from RoleDependentLayer import RoleDependentLayer


class Input(object):
    def __init__(self, object1, object1_fake, action, object2, rng,
                 vovab_length=4000, wordDim=100, trainedWordsVectors=None,):
        # Init Embeding layer, input vector of index and ouput average
        # of word vector as ref Ding et al 2014
        self.EMBD = EmbeddingLayer(vovab_length, wordDim, rng=rng,
                                   embedding_w=trainedWordsVectors)

        object1_vector, _ = self.EMBD.words_ind_2vec(object1)
        action_vector, _ = self.EMBD.words_ind_2vec(action)
        object2_vector, _ = self.EMBD.words_ind_2vec(object2)
        object1_vector_fake, _ = self.EMBD.words_ind_2vec(object1_fake)

        self.output = [object1_vector, object1_vector_fake,
                       action_vector, object2_vector]
        self.params = self.EMBD.params

    def get_params(self):
        trainParams = {
            "WordWvec": self.EMBD.embedding_w.get_value()
        }
        return(trainParams)


class ModelBody(object):
    def __init__(self, vectorObjects, rng, n_out, n_in,
                 trainedModelParams=None):
        if trainedModelParams is None:
            trainedModelParams = {
                "roleDependentLayer1_": {
                    "T": None, "W1": None, "W2": None, "b": None
                },
                "roleDependentLayer2_": {
                    "T": None, "W1": None, "W2": None, "b": None
                },
                "roleDependentLayer3_": {
                    "T": None, "W1": None, "W2": None, "b": None
                }
            }

        Obj1, Ob1_fake, Act, Obj2 = vectorObjects
        
        ##
#         print(trainedModelParams["roleDependentLayer1_"]["T"].shape)
#         print(n_in, n_out)
        self.RoleDepen1 = RoleDependentLayer(
            left_dependent=T.stack([Obj1, Ob1_fake], axis=0),
            right_dependent=Act,
            n_in=n_in, n_out=n_out, rng=rng,
            trainedParams=trainedModelParams,
            name="roleDependentLayer1_"
        )
        self.RoleDepen1_output = self.RoleDepen1.output

        self.RoleDepen2 = RoleDependentLayer(
            left_dependent=Obj2,
            right_dependent=Act,
            n_in=n_in, n_out=n_out, rng=rng,
            trainedParams=trainedModelParams,
            name="roleDependentLayer2_"
        )
        self.RoleDepen2_output = T.flatten(self.RoleDepen2.output, outdim=1)

        self.RoleDepen3 = RoleDependentLayer(
            left_dependent=self.RoleDepen1_output,
            right_dependent=self.RoleDepen2_output,
            n_in=n_out, n_out=n_out, rng=rng,
            trainedParams=trainedModelParams,
            name="roleDependentLayer3_"
        )

        self.params = self.RoleDepen1.params + self.RoleDepen2.params + \
            self.RoleDepen3.params

        self.L2 = (
            self.RoleDepen1.L2 +
            self.RoleDepen2.L2 +
            self.RoleDepen3.L2
        )
        self.output = self.RoleDepen3.output

    def get_params(self):
        trainedModelParams = {
            "roleDependentLayer1_": self.RoleDepen1.get_params(),
            "roleDependentLayer2_": self.RoleDepen2.get_params(),
            "roleDependentLayer3_": self.RoleDepen3.get_params()
        }
        return(trainedModelParams)


class LogisticRegression(object):

    def __init__(self, rng, layerInput, n_in, n_out,
                 paramsLayer=None,
                 name="LogisticRegression_"):

        self.layerInput = layerInput
        if paramsLayer is None:
            self.W = createShareVar(rng=rng, name=name+"W",
                                    factor_for_init=n_out + n_in,
                                    dim=(n_in, n_out))
        else:
            self.W = theano.shared(value=paramsLayer["W"],
                                   name=name+"W", borrow=True)

        if paramsLayer is None:
            b_values = np.zeros((n_out,), dtype=theano.config.floatX)
            self.b = theano.shared(value=b_values,
                                   name=name+"b", borrow=True)
        else:
            self.b = theano.shared(value=paramsLayer["b"],
                                   name=name+"b", borrow=True)

        step1 = T.dot(self.layerInput, self.W)
        self.prob_givenX = T.tanh(step1 + self.b)
        self.y_predict = T.argmax(self.prob_givenX, axis=1)

        self.params = [self.W, self.b]
        self.L2 = sum([(param**2).sum() for param in self.params])

    def get_params(self):
        trainedParams = {
            "W": self.W.get_value(), "b": self.b.get_value()
        }
        return(trainedParams)

    def neg_log_likelihood(self, y_true):
        y_true = T.cast(y_true, "int32")
        log_prob = T.log(self.prob_givenX)
        nll = -T.mean(log_prob[T.arange(y_true.shape[0]), y_true])
        return nll

    def margin_loss(self):
        loss = T.max([0, 1 - self.prob_givenX[0, 0] + self.prob_givenX[1, 0]])
        return loss

    def cal_errors(self, y_true):
        if y_true.ndim != self.y_predict.ndim:
            raise TypeError(
                "y should have the same shape as self.y_pred",
                ("y_true", y_true.ndim, "y_pred", self.y_predict.ndim)
            )
        if y_true.dtype.startswith("int"):
            return T.mean(T.neq(self.y_predict, y_true))
        else:
            raise TypeError(
                "y_true should have type int ...",
                ("y_true", y_true.type, "y_pred", self.y_predict.type)
            )


# def main(dataPath, trainedParamsPath="modelTrained.pickle",
#          outputVectorPath="resultEmbeding.pickle",
#          learning_rate=0.005, L2_reg=0.0001,
#          n_epochs=500, num_K=150, word_dim=150):
def main(dataPath, trainedParamsPath="modelTrained.pickle",
         outputVectorPath="resultEmbeding.pickle",
         learning_rate=0.005, L2_reg=0.0001,
         n_epochs=500, num_K=80, word_dim=150):
    # CONSTANT VARIABLES
    RNG = np.random.RandomState(220495 + 280295 + 1)
    LABEL_NUM = 2
    if os.path.isfile(trainedParamsPath):
        with open(trainedParamsPath, 'rb') as handle:
            trainedParams = pickle.load(handle)
    else:
        print("No Trained Model, create new")
        I2V = np.load('./input/index2vector2.npy')
        trainedParams = {
            "Input": {"WordWvec": I2V}, "Body": None, "Output": None
        }
#     print(trainedParams['Input']['WordWvec'])
    OPTIMIZER = ADAM_OPTIMIZER
    # INPUT DATA
    data_indexed_events = np.load(dataPath, allow_pickle=True)
    
    N_sample = len(data_indexed_events)
#    N_sample = 1
    all_index = []
    for i in data_indexed_events:
        for j in i:
            for k in j:
                all_index.append(k)
    all_index = list(set(all_index))
#     all_index = list(set(np.hstack(data_indexed_events.flat)))
#    all_train_index = list(set(np.hstack(data_indexed_events[0:NNN].flat)))
    # Snip tensor at begin
    object1 = T.ivector("object1")
    object1_fake = T.ivector("object1_fake")
    action = T.ivector("action")
    object2 = T.ivector("object2")

    constainY = theano.shared(
        np.asarray([1, 0], dtype=theano.config.floatX),
        borrow=True
    )

    # WORDS EMBEDING VECTOR
    wordsEmbedLayer = Input(
        object1=object1, object1_fake=object1_fake,
        action=action, object2=object2, rng=RNG,
        wordDim=word_dim, vovab_length=len(all_index),
        trainedWordsVectors=trainedParams["Input"]["WordWvec"]
    )
    
#     print(trainedParams['Input']['WordWvec'])
    Obj1, Ob1_fake, Act, Obj2 = wordsEmbedLayer.output

    # EVENTS EMBEDING LAYER - THREE ROLE DEPENTDENT LAYER
    eventsEmbedingLayer = ModelBody(
        vectorObjects=wordsEmbedLayer.output,
        n_out=num_K, n_in=word_dim, rng=RNG,
        trainedModelParams=trainedParams["Body"]
    )
    
#     print(trainedParams['Input']['WordWvec'])
    # CLASSIFY LAYER
    predict_layers = LogisticRegression(
        layerInput=eventsEmbedingLayer.output,
        rng=RNG, n_in=num_K, n_out=1,
        paramsLayer=trainedParams["Output"]
    )

    # COST FUNCTION
    COST = (
        predict_layers.margin_loss() +
        L2_reg * predict_layers.L2 +
        L2_reg * eventsEmbedingLayer.L2
    )

    # GRADIENT CALCULATION and UPDATE
    all_params = wordsEmbedLayer.params + \
        eventsEmbedingLayer.params + predict_layers.params
    print("TRAIN: ", all_params)

    UPDATE = OPTIMIZER(COST, all_params, learning_rate=learning_rate)

    # TRAIN MODEL
    GET_COST = theano.function(
        inputs=[object1, object1_fake, action, object2],
        outputs=[predict_layers.margin_loss(),
                 predict_layers.prob_givenX],
    )

#    TEST = theano.function(
#        inputs=[object1, object1_fake, action, object2],
#        outputs=eventsEmbedingLayer.RoleDepen2.test,
#        on_unused_input='warn'
#    )

    TRAIN = theano.function(
        inputs=[object1, object1_fake, action, object2],
        outputs=[predict_layers.margin_loss()],
        updates=UPDATE
    )

    GET_EVENT_VECTOR = theano.function(
        inputs=[object1, object1_fake, action, object2],
        outputs=[predict_layers.margin_loss(),
                 eventsEmbedingLayer.output],
    )

    def generate_fake_object(all_index, RNG, obj):
        fake_obj = list(RNG.choice(all_index, len(obj)))
        while sorted(fake_obj) == sorted(obj):
            print("WRONG faking object 1", obj)
            fake_obj = list(RNG.choice(all_index, len(obj)))
        return(fake_obj)

    def generate_list_object(data_indexed_events, all_index, RNG):
        list_fake_object1 = [
            generate_fake_object(all_index, RNG, events[0])
            for events in data_indexed_events
        ]
        list_real_object = set([
            "_".join([str(a) for a in sorted(events[0])])
            for events in data_indexed_events
        ])
        wrong = 0
        while True:
            valid = True
            wrong += 1
            for i, obj in enumerate(list_fake_object1):
                s = "_".join([str(a) for a in sorted(obj)])
                if s in list_real_object:
                    valid = valid and False
                    list_fake_object1[i] = \
                        generate_fake_object(all_index, RNG, s)
                else:
                    valid = valid and True
            if valid:
                break
        print("There are %d wrong random loops" % wrong)
        return(list_fake_object1)

    print("*"*72)
    print("Begin Training process")

    for epoch in range(n_epochs):
        # create false label
        print("Begin new epoch: %d" % epoch)

        list_fake_object1 = generate_list_object(data_indexed_events,
                                                 all_index, RNG)
        cost_of_epoch = []
        set_index = set(range(N_sample))
        temp_variable = N_sample
        print("*" * 72+"\n")
        print("*" * 72+"\n")
        # train
        model_train = {
            "Input": wordsEmbedLayer.get_params(),
            "Body": eventsEmbedingLayer.get_params(),
            "Output": predict_layers.get_params()
        }
        RESULT = {}
        outCOST = []
        Max_inter = len(set_index)*2
        iter_num = 0
        while len(set_index) > 0 and iter_num <= Max_inter:
            iter_num += 1
            index = set_index.pop()
            ob1_real, act, obj2 = data_indexed_events[index]
            ob1_fake = list_fake_object1[index]
            
            ob1_real = np.array(ob1_real, dtype=np.int32)
            ob1_fake = np.array(ob1_fake, dtype=np.int32)
            act = np.array(act, dtype=np.int32)
            obj2 = np.array(obj2, dtype=np.int32)

            cost, probY = GET_COST(ob1_real, ob1_fake, act, obj2)
            outCOST.append(cost)
#            test = TEST(ob1_real, ob1_fake, act, obj2)
#            for a in test:
#                print(a, a.shape)

            if cost > 0:
                set_index.add(index)
                c = TRAIN(ob1_real, ob1_fake, act, obj2)
            else:
                RESULT[index] = GET_EVENT_VECTOR(ob1_real, ob1_fake, act, obj2)

            if (len(set_index) % 50 == 0 and
                    temp_variable != len(set_index)):
                temp_variable = len(set_index)
                print("There are %f %% left in this %d "
                      "epoch with average cost %f"
                      % (len(set_index)/float(N_sample)*100,
                         epoch, np.mean(outCOST[-50:])))
#             if iter_num > Max_inter - 5:
#                 print(set_index, ob1_real, ob1_fake, act, obj2)

        with open(trainedParamsPath, 'wb') as handle:
            pickle.dump(model_train, handle,
                        protocol=pickle.HIGHEST_PROTOCOL)

        with open(outputVectorPath, 'wb') as handle:
            pickle.dump(RESULT, handle,
                        protocol=pickle.HIGHEST_PROTOCOL)

if __name__ == "__main__":
#     arg = ["", "Data/Query_Apple/2005-2010/IndexedEvents.npy",
#           "Data/Query_Apple/2005-2010/linhtinh/", "20"]
#     arg = sys.argv
    arg = ["", "/Users/arthur/Desktop/OpenIEStanza_EventEmbedding/input/event2index2.npy",
          "/Users/arthur/Desktop/OpenIEStanza_EventEmbedding/input/", "1"]
    main(dataPath=arg[1], trainedParamsPath=arg[2]+"TrainedParams2.pickle",
         outputVectorPath=arg[2]+"resultEmbeding2.pickle", n_epochs=int(arg[3]), word_dim=100)
# Out:
# No Trained Model, create new
# /opt/anaconda3/lib/python3.9/site-packages/theano/tensor/basic.py:5280: UserWarning: flatten outdim parameter is deprecated, use ndim instead.
#   warnings.warn(
# TRAIN:  [EmbeddingLayer_W, roleDependentLayer1_T, roleDependentLayer1_W1, roleDependentLayer1_W2, roleDependentLayer1_b, roleDependentLayer2_T, roleDependentLayer2_W1, roleDependentLayer2_W2, roleDependentLayer2_b, roleDependentLayer3_T, roleDependentLayer3_W1, roleDependentLayer3_W2, roleDependentLayer3_b, LogisticRegression_W, LogisticRegression_b]
# ************************************************************************
# Begin Training process
# Begin new epoch: 0
# WRONG faking object 1 [10043]
# There are 3 wrong random loops
# ************************************************************************
#
# ************************************************************************
#
# There are 99.988900 % left in this 0 epoch with average cost 0.994497
# There are 99.967553 % left in this 0 epoch with average cost 0.940352
# There are 99.946206 % left in this 0 epoch with average cost 0.958778
# There are 99.924859 % left in this 0 epoch with average cost 0.781189
# There are 99.903512 % left in this 0 epoch with average cost 0.808288
# There are 99.882165 % left in this 0 epoch with average cost 0.903635
# There are 99.860818 % left in this 0 epoch with average cost 0.785304
# There are 99.839471 % left in this 0 epoch with average cost 0.819213
# There are 99.818124 % left in this 0 epoch with average cost 0.875486
# There are 99.796777 % left in this 0 epoch with average cost 0.817483
# There are 99.775431 % left in this 0 epoch with average cost 0.880416
# There are 99.754084 % left in this 0 epoch with average cost 0.922733
# There are 99.732737 % left in this 0 epoch with average cost 0.934459
# There are 99.711390 % left in this 0 epoch with average cost 0.824011
# There are 99.690043 % left in this 0 epoch with average cost 0.750145
# There are 99.668696 % left in this 0 epoch with average cost 0.789379
# There are 99.647349 % left in this 0 epoch with average cost 0.857304
# There are 99.626002 % left in this 0 epoch with average cost 0.706114
# There are 99.604655 % left in this 0 epoch with average cost 0.754493
# There are 99.583308 % left in this 0 epoch with average cost 0.870011
# There are 99.561962 % left in this 0 epoch with average cost 0.746600
# There are 99.540615 % left in this 0 epoch with average cost 0.807147
# There are 99.519268 % left in this 0 epoch with average cost 0.794000
# There are 99.497921 % left in this 0 epoch with average cost 0.892563
# There are 99.476574 % left in this 0 epoch with average cost 0.818977
# There are 99.455227 % left in this 0 epoch with average cost 0.904730
# There are 99.433880 % left in this 0 epoch with average cost 0.763049
# There are 99.412533 % left in this 0 epoch with average cost 0.895791
# There are 99.391186 % left in this 0 epoch with average cost 0.840760
# There are 99.369839 % left in this 0 epoch with average cost 0.751229
# There are 99.348492 % left in this 0 epoch with average cost 0.939052
# There are 99.327146 % left in this 0 epoch with average cost 0.780606
# There are 99.305799 % left in this 0 epoch with average cost 0.711303
# There are 99.284452 % left in this 0 epoch with average cost 0.794366
# There are 99.263105 % left in this 0 epoch with average cost 0.808803
# There are 99.241758 % left in this 0 epoch with average cost 0.749152
# There are 99.220411 % left in this 0 epoch with average cost 0.600647
# There are 99.199064 % left in this 0 epoch with average cost 0.680285
# There are 99.177717 % left in this 0 epoch with average cost 0.917916
# There are 99.156370 % left in this 0 epoch with average cost 0.998848
# There are 99.135023 % left in this 0 epoch with average cost 0.791406
# There are 99.113677 % left in this 0 epoch with average cost 0.892593
# There are 99.092330 % left in this 0 epoch with average cost 0.867151
# There are 99.070983 % left in this 0 epoch with average cost 1.029349
# There are 99.049636 % left in this 0 epoch with average cost 0.970035
# There are 99.028289 % left in this 0 epoch with average cost 0.775395
# There are 99.006942 % left in this 0 epoch with average cost 0.955795
# There are 98.985595 % left in this 0 epoch with average cost 0.884418
# There are 98.964248 % left in this 0 epoch with average cost 0.833662
# There are 98.942901 % left in this 0 epoch with average cost 0.932117
# There are 98.921554 % left in this 0 epoch with average cost 0.965775
# There are 98.900207 % left in this 0 epoch with average cost 0.882713
# There are 98.878861 % left in this 0 epoch with average cost 0.923893
# There are 98.857514 % left in this 0 epoch with average cost 0.651790
# There are 98.836167 % left in this 0 epoch with average cost 0.972716
# There are 98.814820 % left in this 0 epoch with average cost 0.892935
# There are 98.793473 % left in this 0 epoch with average cost 0.653642
# There are 98.772126 % left in this 0 epoch with average cost 0.724960
# There are 98.750779 % left in this 0 epoch with average cost 0.680158
# There are 98.729432 % left in this 0 epoch with average cost 0.822640
# There are 98.708085 % left in this 0 epoch with average cost 0.843851
# There are 98.686738 % left in this 0 epoch with average cost 0.841143
# There are 98.665392 % left in this 0 epoch with average cost 0.870164
# There are 98.644045 % left in this 0 epoch with average cost 0.785112
# There are 98.622698 % left in this 0 epoch with average cost 0.824831
# There are 98.601351 % left in this 0 epoch with average cost 0.875016
# There are 98.580004 % left in this 0 epoch with average cost 0.893147
# There are 98.558657 % left in this 0 epoch with average cost 0.904907
# There are 98.537310 % left in this 0 epoch with average cost 0.776322
# There are 98.515963 % left in this 0 epoch with average cost 0.854220
# There are 98.494616 % left in this 0 epoch with average cost 0.758102
# There are 98.473269 % left in this 0 epoch with average cost 0.774935
# There are 98.451923 % left in this 0 epoch with average cost 0.704132
# There are 98.430576 % left in this 0 epoch with average cost 0.775926
# There are 98.409229 % left in this 0 epoch with average cost 0.830202
# There are 98.387882 % left in this 0 epoch with average cost 0.773439
# There are 98.366535 % left in this 0 epoch with average cost 0.627831
# There are 98.345188 % left in this 0 epoch with average cost 0.571187
# There are 98.323841 % left in this 0 epoch with average cost 0.652723
# There are 98.302494 % left in this 0 epoch with average cost 0.533142
# There are 98.281147 % left in this 0 epoch with average cost 0.806528
# There are 98.259800 % left in this 0 epoch with average cost 0.708184
# There are 98.238453 % left in this 0 epoch with average cost 0.869140
# There are 98.217107 % left in this 0 epoch with average cost 0.828423
# There are 98.195760 % left in this 0 epoch with average cost 0.639541
# There are 98.174413 % left in this 0 epoch with average cost 0.588522
# There are 98.153066 % left in this 0 epoch with average cost 0.926313
# There are 98.131719 % left in this 0 epoch with average cost 0.645741
# There are 98.110372 % left in this 0 epoch with average cost 0.930910
# There are 98.089025 % left in this 0 epoch with average cost 0.712331
# There are 98.067678 % left in this 0 epoch with average cost 0.993482
# There are 98.046331 % left in this 0 epoch with average cost 0.694124
# There are 98.024984 % left in this 0 epoch with average cost 0.876594
# There are 98.003638 % left in this 0 epoch with average cost 0.693823
# There are 97.982291 % left in this 0 epoch with average cost 0.640755
# There are 97.960944 % left in this 0 epoch with average cost 0.738857
# There are 97.939597 % left in this 0 epoch with average cost 0.531333
# There are 97.918250 % left in this 0 epoch with average cost 0.660418
# There are 97.896903 % left in this 0 epoch with average cost 0.649252
# There are 97.875556 % left in this 0 epoch with average cost 0.743513
# There are 97.854209 % left in this 0 epoch with average cost 0.772078
# There are 97.832862 % left in this 0 epoch with average cost 0.902869
# There are 97.811515 % left in this 0 epoch with average cost 0.716547
# There are 97.790168 % left in this 0 epoch with average cost 0.558943
# There are 97.768822 % left in this 0 epoch with average cost 0.816682
# There are 97.747475 % left in this 0 epoch with average cost 0.669690
# There are 97.726128 % left in this 0 epoch with average cost 0.803517
# There are 97.704781 % left in this 0 epoch with average cost 0.896013
# There are 97.683434 % left in this 0 epoch with average cost 0.840590
# There are 97.662087 % left in this 0 epoch with average cost 0.771658
# There are 97.640740 % left in this 0 epoch with average cost 0.869062
# There are 97.619393 % left in this 0 epoch with average cost 0.733250
# There are 97.598046 % left in this 0 epoch with average cost 0.693047
# There are 97.576699 % left in this 0 epoch with average cost 0.695091
# There are 97.555353 % left in this 0 epoch with average cost 0.757587
# There are 97.534006 % left in this 0 epoch with average cost 0.768900
# There are 97.512659 % left in this 0 epoch with average cost 0.670560
# There are 97.491312 % left in this 0 epoch with average cost 0.754829
# There are 97.469965 % left in this 0 epoch with average cost 0.610387
# There are 97.448618 % left in this 0 epoch with average cost 0.788405
# There are 97.427271 % left in this 0 epoch with average cost 0.669968
# There are 97.405924 % left in this 0 epoch with average cost 0.669349
# There are 97.384577 % left in this 0 epoch with average cost 0.898041
# There are 97.363230 % left in this 0 epoch with average cost 0.798827
# There are 97.341883 % left in this 0 epoch with average cost 0.785601
# There are 97.320537 % left in this 0 epoch with average cost 0.901407
# There are 97.299190 % left in this 0 epoch with average cost 0.723489
# There are 97.277843 % left in this 0 epoch with average cost 0.829842
# There are 97.256496 % left in this 0 epoch with average cost 0.707593
# There are 97.235149 % left in this 0 epoch with average cost 0.981108
# There are 97.213802 % left in this 0 epoch with average cost 0.778736
# There are 97.192455 % left in this 0 epoch with average cost 0.754960
# There are 97.171108 % left in this 0 epoch with average cost 0.832788
# There are 97.149761 % left in this 0 epoch with average cost 0.788044
# There are 97.128414 % left in this 0 epoch with average cost 0.571321
# There are 97.107068 % left in this 0 epoch with average cost 0.784299
# There are 97.085721 % left in this 0 epoch with average cost 0.863122
# There are 97.064374 % left in this 0 epoch with average cost 0.728419
# There are 97.043027 % left in this 0 epoch with average cost 0.729283
# There are 97.021680 % left in this 0 epoch with average cost 0.773665
# There are 97.000333 % left in this 0 epoch with average cost 0.961471
# There are 96.978986 % left in this 0 epoch with average cost 0.689113
# There are 96.957639 % left in this 0 epoch with average cost 0.766481
# There are 96.936292 % left in this 0 epoch with average cost 0.837532
# There are 96.914945 % left in this 0 epoch with average cost 0.824545
# There are 96.893598 % left in this 0 epoch with average cost 0.776962
# There are 96.872252 % left in this 0 epoch with average cost 0.787034
# There are 96.850905 % left in this 0 epoch with average cost 0.820859
# There are 96.829558 % left in this 0 epoch with average cost 0.779310
# There are 96.808211 % left in this 0 epoch with average cost 0.921827
# There are 96.786864 % left in this 0 epoch with average cost 0.644685
# There are 96.765517 % left in this 0 epoch with average cost 0.832995
# There are 96.744170 % left in this 0 epoch with average cost 0.664616
# There are 96.722823 % left in this 0 epoch with average cost 0.792074
# There are 96.701476 % left in this 0 epoch with average cost 0.762692
# There are 96.680129 % left in this 0 epoch with average cost 0.789931
# There are 96.658783 % left in this 0 epoch with average cost 0.687751
# There are 96.637436 % left in this 0 epoch with average cost 0.807813
# There are 96.616089 % left in this 0 epoch with average cost 0.833224
# There are 96.594742 % left in this 0 epoch with average cost 0.886603
# There are 96.573395 % left in this 0 epoch with average cost 0.651193
# There are 96.552048 % left in this 0 epoch with average cost 0.640701
# There are 96.530701 % left in this 0 epoch with average cost 1.050558
# There are 96.509354 % left in this 0 epoch with average cost 0.682629
# There are 96.488007 % left in this 0 epoch with average cost 0.745850
# There are 96.466660 % left in this 0 epoch with average cost 0.988184
# There are 96.445314 % left in this 0 epoch with average cost 1.152708
# There are 96.423967 % left in this 0 epoch with average cost 0.881610
# There are 96.402620 % left in this 0 epoch with average cost 0.843109
# There are 96.381273 % left in this 0 epoch with average cost 0.814549
# There are 96.359926 % left in this 0 epoch with average cost 0.937545
# There are 96.338579 % left in this 0 epoch with average cost 0.645478
# There are 96.317232 % left in this 0 epoch with average cost 0.663117
# There are 96.295885 % left in this 0 epoch with average cost 0.692962
# There are 96.274538 % left in this 0 epoch with average cost 0.695179
# There are 96.253191 % left in this 0 epoch with average cost 0.724859
# There are 96.231844 % left in this 0 epoch with average cost 0.830049
# There are 96.210498 % left in this 0 epoch with average cost 0.664604
# There are 96.189151 % left in this 0 epoch with average cost 0.722411
# There are 96.167804 % left in this 0 epoch with average cost 0.652881
# There are 96.146457 % left in this 0 epoch with average cost 0.748168
# There are 96.125110 % left in this 0 epoch with average cost 0.725534
# There are 96.103763 % left in this 0 epoch with average cost 0.808642
# There are 96.082416 % left in this 0 epoch with average cost 0.805115
# There are 96.061069 % left in this 0 epoch with average cost 0.669139
# There are 96.039722 % left in this 0 epoch with average cost 0.711833
# There are 96.018375 % left in this 0 epoch with average cost 0.921864
# There are 95.997029 % left in this 0 epoch with average cost 0.692634
# There are 95.975682 % left in this 0 epoch with average cost 0.729017
# There are 95.954335 % left in this 0 epoch with average cost 0.815753
# There are 95.932988 % left in this 0 epoch with average cost 0.812187
# There are 95.911641 % left in this 0 epoch with average cost 0.621869
# There are 95.890294 % left in this 0 epoch with average cost 0.799239
# There are 95.868947 % left in this 0 epoch with average cost 0.801292
# There are 95.847600 % left in this 0 epoch with average cost 0.721032
# There are 95.826253 % left in this 0 epoch with average cost 0.802168
# There are 95.804906 % left in this 0 epoch with average cost 0.574181
# There are 95.783559 % left in this 0 epoch with average cost 0.814094
# There are 95.762213 % left in this 0 epoch with average cost 0.738472
# There are 95.740866 % left in this 0 epoch with average cost 0.702615
# There are 95.719519 % left in this 0 epoch with average cost 0.639009
# There are 95.698172 % left in this 0 epoch with average cost 0.801829
# There are 95.676825 % left in this 0 epoch with average cost 0.761474
# There are 95.655478 % left in this 0 epoch with average cost 0.693201
# There are 95.634131 % left in this 0 epoch with average cost 0.788455
# There are 95.612784 % left in this 0 epoch with average cost 0.834838
# There are 95.591437 % left in this 0 epoch with average cost 0.781843
# There are 95.570090 % left in this 0 epoch with average cost 0.812121
# There are 95.548744 % left in this 0 epoch with average cost 0.790732
# There are 95.527397 % left in this 0 epoch with average cost 0.723044
# There are 95.506050 % left in this 0 epoch with average cost 0.784482
# There are 95.484703 % left in this 0 epoch with average cost 0.845634
# There are 95.463356 % left in this 0 epoch with average cost 0.904357
# There are 95.442009 % left in this 0 epoch with average cost 0.682598
# There are 95.420662 % left in this 0 epoch with average cost 0.819416
# There are 95.399315 % left in this 0 epoch with average cost 0.892558
# There are 95.377968 % left in this 0 epoch with average cost 0.797870
# There are 95.356621 % left in this 0 epoch with average cost 0.754632
# There are 95.335274 % left in this 0 epoch with average cost 0.758667
# There are 95.313928 % left in this 0 epoch with average cost 0.766180
# There are 95.292581 % left in this 0 epoch with average cost 0.722807
# There are 95.271234 % left in this 0 epoch with average cost 0.557125
# There are 95.249887 % left in this 0 epoch with average cost 0.830108
# There are 95.228540 % left in this 0 epoch with average cost 0.788128
# There are 95.207193 % left in this 0 epoch with average cost 0.685725
# There are 95.185846 % left in this 0 epoch with average cost 0.609369
# There are 95.164499 % left in this 0 epoch with average cost 0.771365
# There are 95.143152 % left in this 0 epoch with average cost 0.733846
# There are 95.121805 % left in this 0 epoch with average cost 0.749346
# There are 95.100459 % left in this 0 epoch with average cost 0.754251
# There are 95.079112 % left in this 0 epoch with average cost 0.818450
# There are 95.057765 % left in this 0 epoch with average cost 0.787683
# There are 95.036418 % left in this 0 epoch with average cost 0.866281
# There are 95.015071 % left in this 0 epoch with average cost 0.835504
# There are 94.993724 % left in this 0 epoch with average cost 0.620011
# There are 94.972377 % left in this 0 epoch with average cost 0.872610
# There are 94.951030 % left in this 0 epoch with average cost 0.868929
# There are 94.929683 % left in this 0 epoch with average cost 0.738596
# There are 94.908336 % left in this 0 epoch with average cost 0.785501
# There are 94.886989 % left in this 0 epoch with average cost 0.631302
# There are 94.865643 % left in this 0 epoch with average cost 0.791351
# There are 94.844296 % left in this 0 epoch with average cost 0.780522
# There are 94.822949 % left in this 0 epoch with average cost 0.896529
# There are 94.801602 % left in this 0 epoch with average cost 0.669619
# There are 94.780255 % left in this 0 epoch with average cost 0.724636
# There are 94.758908 % left in this 0 epoch with average cost 0.845452
# There are 94.737561 % left in this 0 epoch with average cost 0.867319
# There are 94.716214 % left in this 0 epoch with average cost 0.720688
# There are 94.694867 % left in this 0 epoch with average cost 0.844513
# There are 94.673520 % left in this 0 epoch with average cost 0.892173
# There are 94.652174 % left in this 0 epoch with average cost 0.849098
# There are 94.630827 % left in this 0 epoch with average cost 0.724856
# There are 94.609480 % left in this 0 epoch with average cost 0.731860
# There are 94.588133 % left in this 0 epoch with average cost 0.675366
# There are 94.566786 % left in this 0 epoch with average cost 0.846769
# There are 94.545439 % left in this 0 epoch with average cost 0.651710
# There are 94.524092 % left in this 0 epoch with average cost 0.760664
# There are 94.502745 % left in this 0 epoch with average cost 0.684635
# There are 94.481398 % left in this 0 epoch with average cost 0.570390
# There are 94.460051 % left in this 0 epoch with average cost 0.685889
# There are 94.438704 % left in this 0 epoch with average cost 0.678526
# There are 94.417358 % left in this 0 epoch with average cost 0.628075
# There are 94.396011 % left in this 0 epoch with average cost 0.847588
# There are 94.374664 % left in this 0 epoch with average cost 0.606953
# There are 94.353317 % left in this 0 epoch with average cost 0.765600
# There are 94.331970 % left in this 0 epoch with average cost 0.637903
# There are 94.310623 % left in this 0 epoch with average cost 0.588657
# There are 94.289276 % left in this 0 epoch with average cost 0.944332
# There are 94.267929 % left in this 0 epoch with average cost 0.779666
# There are 94.246582 % left in this 0 epoch with average cost 0.926474
# There are 94.225235 % left in this 0 epoch with average cost 0.679343
# There are 94.203889 % left in this 0 epoch with average cost 0.729803
# There are 94.182542 % left in this 0 epoch with average cost 0.622116
# There are 94.161195 % left in this 0 epoch with average cost 1.070788
# There are 94.139848 % left in this 0 epoch with average cost 0.730441
# There are 94.118501 % left in this 0 epoch with average cost 0.786525
# There are 94.097154 % left in this 0 epoch with average cost 0.716077
# There are 94.075807 % left in this 0 epoch with average cost 0.785602
# There are 94.054460 % left in this 0 epoch with average cost 0.779431
# There are 94.033113 % left in this 0 epoch with average cost 0.628420
# There are 94.011766 % left in this 0 epoch with average cost 0.765843
# There are 93.990420 % left in this 0 epoch with average cost 0.963459
# There are 93.969073 % left in this 0 epoch with average cost 0.835359
# There are 93.947726 % left in this 0 epoch with average cost 0.843712
# There are 93.926379 % left in this 0 epoch with average cost 0.608098
# There are 93.905032 % left in this 0 epoch with average cost 0.721834
# There are 93.883685 % left in this 0 epoch with average cost 0.685278
# There are 93.862338 % left in this 0 epoch with average cost 0.838164
# There are 93.840991 % left in this 0 epoch with average cost 0.730655
# There are 93.819644 % left in this 0 epoch with average cost 0.760450
# There are 93.798297 % left in this 0 epoch with average cost 0.759954
# There are 93.776950 % left in this 0 epoch with average cost 0.904392
# There are 93.755604 % left in this 0 epoch with average cost 0.805768
# There are 93.734257 % left in this 0 epoch with average cost 0.663804
# There are 93.712910 % left in this 0 epoch with average cost 0.593464
# There are 93.691563 % left in this 0 epoch with average cost 0.582040
# There are 93.670216 % left in this 0 epoch with average cost 0.829526
# There are 93.648869 % left in this 0 epoch with average cost 0.647718
# There are 93.627522 % left in this 0 epoch with average cost 0.542825
# There are 93.606175 % left in this 0 epoch with average cost 0.627607
# There are 93.584828 % left in this 0 epoch with average cost 0.735612
# There are 93.563481 % left in this 0 epoch with average cost 0.611267
# There are 93.542135 % left in this 0 epoch with average cost 0.658036
# There are 93.520788 % left in this 0 epoch with average cost 0.787287
# There are 93.499441 % left in this 0 epoch with average cost 0.714894
# There are 93.478094 % left in this 0 epoch with average cost 0.744286
# There are 93.456747 % left in this 0 epoch with average cost 0.824013
# There are 93.435400 % left in this 0 epoch with average cost 0.641429
# There are 93.414053 % left in this 0 epoch with average cost 0.683667
# There are 93.392706 % left in this 0 epoch with average cost 0.731684
# There are 93.371359 % left in this 0 epoch with average cost 0.661156
# There are 93.350012 % left in this 0 epoch with average cost 0.717457
# There are 93.328665 % left in this 0 epoch with average cost 0.770052
# There are 93.307319 % left in this 0 epoch with average cost 0.641810
# There are 93.285972 % left in this 0 epoch with average cost 0.766638
# There are 93.264625 % left in this 0 epoch with average cost 0.757220
# There are 93.243278 % left in this 0 epoch with average cost 0.557186
# There are 93.221931 % left in this 0 epoch with average cost 0.777110
# There are 93.200584 % left in this 0 epoch with average cost 0.755215
# There are 93.179237 % left in this 0 epoch with average cost 0.793855
# There are 93.157890 % left in this 0 epoch with average cost 0.666758
# There are 93.136543 % left in this 0 epoch with average cost 0.795947
# There are 93.115196 % left in this 0 epoch with average cost 0.684081
# There are 93.093850 % left in this 0 epoch with average cost 0.820415
# There are 93.072503 % left in this 0 epoch with average cost 0.821777
# There are 93.051156 % left in this 0 epoch with average cost 0.645426
# There are 93.029809 % left in this 0 epoch with average cost 0.617307
# There are 93.008462 % left in this 0 epoch with average cost 1.037362
# There are 92.987115 % left in this 0 epoch with average cost 0.782225
# There are 92.965768 % left in this 0 epoch with average cost 0.687049
# There are 92.944421 % left in this 0 epoch with average cost 0.678861
# There are 92.923074 % left in this 0 epoch with average cost 0.686501
# There are 92.901727 % left in this 0 epoch with average cost 0.843939
# There are 92.880380 % left in this 0 epoch with average cost 0.674452
# There are 92.859034 % left in this 0 epoch with average cost 0.660063
# There are 92.837687 % left in this 0 epoch with average cost 0.512498
# There are 92.816340 % left in this 0 epoch with average cost 0.822855
# There are 92.794993 % left in this 0 epoch with average cost 0.747046
# There are 92.773646 % left in this 0 epoch with average cost 0.776717
# There are 92.752299 % left in this 0 epoch with average cost 0.776518
# There are 92.730952 % left in this 0 epoch with average cost 0.867375
# There are 92.709605 % left in this 0 epoch with average cost 0.873810
# There are 92.688258 % left in this 0 epoch with average cost 0.922419
# There are 92.666911 % left in this 0 epoch with average cost 0.787193
# There are 92.645565 % left in this 0 epoch with average cost 0.734807
# There are 92.624218 % left in this 0 epoch with average cost 0.575135
# There are 92.602871 % left in this 0 epoch with average cost 0.685799
# There are 92.581524 % left in this 0 epoch with average cost 0.668483
# There are 92.560177 % left in this 0 epoch with average cost 0.942297
# There are 92.538830 % left in this 0 epoch with average cost 0.801527
# There are 92.517483 % left in this 0 epoch with average cost 0.594946
# There are 92.496136 % left in this 0 epoch with average cost 0.636710
# There are 92.474789 % left in this 0 epoch with average cost 0.669309
# There are 92.453442 % left in this 0 epoch with average cost 0.708568
# There are 92.432095 % left in this 0 epoch with average cost 0.579037
# There are 92.410749 % left in this 0 epoch with average cost 0.819234
# There are 92.389402 % left in this 0 epoch with average cost 0.572697
# There are 92.368055 % left in this 0 epoch with average cost 0.895907
# There are 92.346708 % left in this 0 epoch with average cost 0.878170
# There are 92.325361 % left in this 0 epoch with average cost 0.795997
# There are 92.304014 % left in this 0 epoch with average cost 0.919511
# There are 92.282667 % left in this 0 epoch with average cost 0.726124
# There are 92.261320 % left in this 0 epoch with average cost 0.610318
# There are 92.239973 % left in this 0 epoch with average cost 0.578590
# There are 92.218626 % left in this 0 epoch with average cost 0.797762
# There are 92.197280 % left in this 0 epoch with average cost 0.560878
# There are 92.175933 % left in this 0 epoch with average cost 0.709831
# There are 92.154586 % left in this 0 epoch with average cost 0.736324
# There are 92.133239 % left in this 0 epoch with average cost 0.735756
# There are 92.111892 % left in this 0 epoch with average cost 0.798809
# There are 92.090545 % left in this 0 epoch with average cost 0.680346
# There are 92.069198 % left in this 0 epoch with average cost 0.817079
# There are 92.047851 % left in this 0 epoch with average cost 0.731911
# There are 92.026504 % left in this 0 epoch with average cost 0.833324
# There are 92.005157 % left in this 0 epoch with average cost 0.764600
# There are 91.983811 % left in this 0 epoch with average cost 0.808804
# There are 91.962464 % left in this 0 epoch with average cost 0.805763
# There are 91.941117 % left in this 0 epoch with average cost 0.569963
# There are 91.919770 % left in this 0 epoch with average cost 0.647429
# There are 91.898423 % left in this 0 epoch with average cost 0.809377
# There are 91.877076 % left in this 0 epoch with average cost 0.548216
# There are 91.855729 % left in this 0 epoch with average cost 0.828496
# There are 91.834382 % left in this 0 epoch with average cost 0.766957
# There are 91.813035 % left in this 0 epoch with average cost 0.653594
# There are 91.791688 % left in this 0 epoch with average cost 0.612114
# There are 91.770341 % left in this 0 epoch with average cost 0.630467
# There are 91.748995 % left in this 0 epoch with average cost 0.593054
# There are 91.727648 % left in this 0 epoch with average cost 0.681269
# There are 91.706301 % left in this 0 epoch with average cost 0.699805
# There are 91.684954 % left in this 0 epoch with average cost 0.599264
# There are 91.663607 % left in this 0 epoch with average cost 0.730781
# There are 91.642260 % left in this 0 epoch with average cost 0.622674
# There are 91.620913 % left in this 0 epoch with average cost 0.662087
# There are 91.599566 % left in this 0 epoch with average cost 0.841980
# There are 91.578219 % left in this 0 epoch with average cost 0.623944
# There are 91.556872 % left in this 0 epoch with average cost 0.774793
# There are 91.535526 % left in this 0 epoch with average cost 0.714944
# There are 91.514179 % left in this 0 epoch with average cost 0.534652
# There are 91.492832 % left in this 0 epoch with average cost 0.769272
# There are 91.471485 % left in this 0 epoch with average cost 0.546492
# There are 91.450138 % left in this 0 epoch with average cost 0.537534
# There are 91.428791 % left in this 0 epoch with average cost 0.706762
# There are 91.407444 % left in this 0 epoch with average cost 0.721527
# There are 91.386097 % left in this 0 epoch with average cost 0.676914
# There are 91.364750 % left in this 0 epoch with average cost 0.747961
# There are 91.343403 % left in this 0 epoch with average cost 0.844056
# There are 91.322056 % left in this 0 epoch with average cost 1.057500
# There are 91.300710 % left in this 0 epoch with average cost 0.592342
# There are 91.279363 % left in this 0 epoch with average cost 0.880270
# There are 91.258016 % left in this 0 epoch with average cost 0.780938
# There are 91.236669 % left in this 0 epoch with average cost 0.776332
# There are 91.215322 % left in this 0 epoch with average cost 0.638717
# There are 91.193975 % left in this 0 epoch with average cost 0.744700
# There are 91.172628 % left in this 0 epoch with average cost 0.895194
# There are 91.151281 % left in this 0 epoch with average cost 0.727334
# There are 91.129934 % left in this 0 epoch with average cost 0.831833
# There are 91.108587 % left in this 0 epoch with average cost 0.707206
# There are 91.087241 % left in this 0 epoch with average cost 0.653051
# There are 91.065894 % left in this 0 epoch with average cost 0.830317
# There are 91.044547 % left in this 0 epoch with average cost 0.615146
# There are 91.023200 % left in this 0 epoch with average cost 0.695104
# There are 91.001853 % left in this 0 epoch with average cost 0.670571
# There are 90.980506 % left in this 0 epoch with average cost 0.809804
# There are 90.959159 % left in this 0 epoch with average cost 0.742722
# There are 90.937812 % left in this 0 epoch with average cost 0.699520
# There are 90.916465 % left in this 0 epoch with average cost 0.797431
# There are 90.895118 % left in this 0 epoch with average cost 0.761879
# There are 90.873771 % left in this 0 epoch with average cost 0.638731
# There are 90.852425 % left in this 0 epoch with average cost 0.508864
# There are 90.831078 % left in this 0 epoch with average cost 0.587488
# There are 90.809731 % left in this 0 epoch with average cost 0.695002
# There are 90.788384 % left in this 0 epoch with average cost 0.762641
# There are 90.767037 % left in this 0 epoch with average cost 0.818378
# There are 90.745690 % left in this 0 epoch with average cost 0.665528
# There are 90.724343 % left in this 0 epoch with average cost 0.820288
# There are 90.702996 % left in this 0 epoch with average cost 0.789106
# There are 90.681649 % left in this 0 epoch with average cost 0.652383
# There are 90.660302 % left in this 0 epoch with average cost 0.737256
# There are 90.638956 % left in this 0 epoch with average cost 0.789494
# There are 90.617609 % left in this 0 epoch with average cost 0.546849
# There are 90.596262 % left in this 0 epoch with average cost 0.699879
# There are 90.574915 % left in this 0 epoch with average cost 0.678832
# There are 90.553568 % left in this 0 epoch with average cost 0.749236
# There are 90.532221 % left in this 0 epoch with average cost 0.917583
# There are 90.510874 % left in this 0 epoch with average cost 0.761031
# There are 90.489527 % left in this 0 epoch with average cost 0.704816
# There are 90.468180 % left in this 0 epoch with average cost 0.781762
# There are 90.446833 % left in this 0 epoch with average cost 0.749721
# There are 90.425486 % left in this 0 epoch with average cost 0.740065
# There are 90.404140 % left in this 0 epoch with average cost 0.627880
# There are 90.382793 % left in this 0 epoch with average cost 0.734979
# There are 90.361446 % left in this 0 epoch with average cost 0.859036
# There are 90.340099 % left in this 0 epoch with average cost 0.588314
# There are 90.318752 % left in this 0 epoch with average cost 0.747189
# There are 90.297405 % left in this 0 epoch with average cost 0.694506
# There are 90.276058 % left in this 0 epoch with average cost 0.845990
# There are 90.254711 % left in this 0 epoch with average cost 0.712566
# There are 90.233364 % left in this 0 epoch with average cost 0.807249
# There are 90.212017 % left in this 0 epoch with average cost 0.673541
# There are 90.190671 % left in this 0 epoch with average cost 0.700440
# There are 90.169324 % left in this 0 epoch with average cost 0.699870
# There are 90.147977 % left in this 0 epoch with average cost 0.570031
# There are 90.126630 % left in this 0 epoch with average cost 0.636070
# There are 90.105283 % left in this 0 epoch with average cost 0.603029
# There are 90.083936 % left in this 0 epoch with average cost 0.846683
# There are 90.062589 % left in this 0 epoch with average cost 0.747341
# There are 90.041242 % left in this 0 epoch with average cost 0.811997
# There are 90.019895 % left in this 0 epoch with average cost 0.755912
# There are 89.998548 % left in this 0 epoch with average cost 0.679138
# There are 89.977202 % left in this 0 epoch with average cost 0.799716
# There are 89.955855 % left in this 0 epoch with average cost 0.715542
# There are 89.934508 % left in this 0 epoch with average cost 0.794693
# There are 89.913161 % left in this 0 epoch with average cost 0.782743
# There are 89.891814 % left in this 0 epoch with average cost 0.818303
# There are 89.870467 % left in this 0 epoch with average cost 0.831712
# There are 89.849120 % left in this 0 epoch with average cost 0.651800
# There are 89.827773 % left in this 0 epoch with average cost 0.637402
# There are 89.806426 % left in this 0 epoch with average cost 0.771079
# There are 89.785079 % left in this 0 epoch with average cost 0.745933
# There are 89.763732 % left in this 0 epoch with average cost 0.834253
# There are 89.742386 % left in this 0 epoch with average cost 0.727956
# There are 89.721039 % left in this 0 epoch with average cost 0.789512
# There are 89.699692 % left in this 0 epoch with average cost 0.610764
# There are 89.678345 % left in this 0 epoch with average cost 0.755492
# There are 89.656998 % left in this 0 epoch with average cost 0.589110
# There are 89.635651 % left in this 0 epoch with average cost 0.885045
# There are 89.614304 % left in this 0 epoch with average cost 0.740631
# There are 89.592957 % left in this 0 epoch with average cost 0.783699
# There are 89.571610 % left in this 0 epoch with average cost 0.687486
# There are 89.550263 % left in this 0 epoch with average cost 0.790629
# There are 89.528917 % left in this 0 epoch with average cost 0.763468
# There are 89.507570 % left in this 0 epoch with average cost 0.974530
# There are 89.486223 % left in this 0 epoch with average cost 0.742334
# There are 89.464876 % left in this 0 epoch with average cost 0.650676
# There are 89.443529 % left in this 0 epoch with average cost 0.655605
# There are 89.422182 % left in this 0 epoch with average cost 0.750623
# There are 89.400835 % left in this 0 epoch with average cost 0.653182
# There are 89.379488 % left in this 0 epoch with average cost 0.697629
# There are 89.358141 % left in this 0 epoch with average cost 0.656114
# There are 89.336794 % left in this 0 epoch with average cost 0.757242
# There are 89.315447 % left in this 0 epoch with average cost 0.608615
# There are 89.294101 % left in this 0 epoch with average cost 0.716508
# There are 89.272754 % left in this 0 epoch with average cost 0.787955
# There are 89.251407 % left in this 0 epoch with average cost 0.668209
# There are 89.230060 % left in this 0 epoch with average cost 0.758004
# There are 89.208713 % left in this 0 epoch with average cost 0.784154
# There are 89.187366 % left in this 0 epoch with average cost 0.788340
# There are 89.166019 % left in this 0 epoch with average cost 0.779066
# There are 89.144672 % left in this 0 epoch with average cost 0.786874
# There are 89.123325 % left in this 0 epoch with average cost 0.700931
# There are 89.101978 % left in this 0 epoch with average cost 0.649439
# There are 89.080632 % left in this 0 epoch with average cost 0.610662
# There are 89.059285 % left in this 0 epoch with average cost 0.707490
# There are 89.037938 % left in this 0 epoch with average cost 0.679046
# There are 89.016591 % left in this 0 epoch with average cost 0.674687
# There are 88.995244 % left in this 0 epoch with average cost 0.918804
# There are 88.973897 % left in this 0 epoch with average cost 0.767360
# There are 88.952550 % left in this 0 epoch with average cost 0.724051
# There are 88.931203 % left in this 0 epoch with average cost 0.740630
# There are 88.909856 % left in this 0 epoch with average cost 0.764234
# There are 88.888509 % left in this 0 epoch with average cost 0.728684
# There are 88.867162 % left in this 0 epoch with average cost 0.601944
# There are 88.845816 % left in this 0 epoch with average cost 0.819615
# There are 88.824469 % left in this 0 epoch with average cost 0.689944
# There are 88.803122 % left in this 0 epoch with average cost 0.689649
# There are 88.781775 % left in this 0 epoch with average cost 0.734815
# There are 88.760428 % left in this 0 epoch with average cost 0.697842
# There are 88.739081 % left in this 0 epoch with average cost 0.675882
# There are 88.717734 % left in this 0 epoch with average cost 0.641777
# There are 88.696387 % left in this 0 epoch with average cost 0.440684
# There are 88.675040 % left in this 0 epoch with average cost 0.652119
# There are 88.653693 % left in this 0 epoch with average cost 0.695208
# There are 88.632347 % left in this 0 epoch with average cost 0.670882
# There are 88.611000 % left in this 0 epoch with average cost 0.613279
# There are 88.589653 % left in this 0 epoch with average cost 0.793760
# There are 88.568306 % left in this 0 epoch with average cost 0.615496
# There are 88.546959 % left in this 0 epoch with average cost 0.663766
# There are 88.525612 % left in this 0 epoch with average cost 0.810339
# There are 88.504265 % left in this 0 epoch with average cost 0.681307
# There are 88.482918 % left in this 0 epoch with average cost 0.690488
# There are 88.461571 % left in this 0 epoch with average cost 0.790705
# There are 88.440224 % left in this 0 epoch with average cost 0.916073
# There are 88.418877 % left in this 0 epoch with average cost 0.786643
# There are 88.397531 % left in this 0 epoch with average cost 0.811304
# There are 88.376184 % left in this 0 epoch with average cost 0.656472
# There are 88.354837 % left in this 0 epoch with average cost 0.537975
# There are 88.333490 % left in this 0 epoch with average cost 0.622085
# There are 88.312143 % left in this 0 epoch with average cost 0.603441
# There are 88.290796 % left in this 0 epoch with average cost 0.777735
# There are 88.269449 % left in this 0 epoch with average cost 0.672605
# There are 88.248102 % left in this 0 epoch with average cost 0.823260
# There are 88.226755 % left in this 0 epoch with average cost 0.541968
# There are 88.205408 % left in this 0 epoch with average cost 0.702700
# There are 88.184062 % left in this 0 epoch with average cost 0.772757
# There are 88.162715 % left in this 0 epoch with average cost 0.627632
# There are 88.141368 % left in this 0 epoch with average cost 0.703746
# There are 88.120021 % left in this 0 epoch with average cost 0.713874
# There are 88.098674 % left in this 0 epoch with average cost 0.861346
# There are 88.077327 % left in this 0 epoch with average cost 0.639478
# There are 88.055980 % left in this 0 epoch with average cost 0.725731
# There are 88.034633 % left in this 0 epoch with average cost 0.774939
# There are 88.013286 % left in this 0 epoch with average cost 0.972055
# There are 87.991939 % left in this 0 epoch with average cost 0.734303
# There are 87.970593 % left in this 0 epoch with average cost 0.746943
# There are 87.949246 % left in this 0 epoch with average cost 0.824872
# There are 87.927899 % left in this 0 epoch with average cost 0.816967
# There are 87.906552 % left in this 0 epoch with average cost 0.624160
# There are 87.885205 % left in this 0 epoch with average cost 0.716504
# There are 87.863858 % left in this 0 epoch with average cost 0.763952
# There are 87.842511 % left in this 0 epoch with average cost 0.652845
# There are 87.821164 % left in this 0 epoch with average cost 0.837953
# There are 87.799817 % left in this 0 epoch with average cost 0.507778
# There are 87.778470 % left in this 0 epoch with average cost 0.737709
# There are 87.757123 % left in this 0 epoch with average cost 0.832637
# There are 87.735777 % left in this 0 epoch with average cost 0.800057
# There are 87.714430 % left in this 0 epoch with average cost 0.578629
# There are 87.693083 % left in this 0 epoch with average cost 0.754208
# There are 87.671736 % left in this 0 epoch with average cost 0.683379
# There are 87.650389 % left in this 0 epoch with average cost 0.457128
# There are 87.629042 % left in this 0 epoch with average cost 0.868330
# There are 87.607695 % left in this 0 epoch with average cost 0.681166
# There are 87.586348 % left in this 0 epoch with average cost 0.747666
# There are 87.565001 % left in this 0 epoch with average cost 0.732531
# There are 87.543654 % left in this 0 epoch with average cost 0.897894
# There are 87.522308 % left in this 0 epoch with average cost 0.771406
# There are 87.500961 % left in this 0 epoch with average cost 0.898862
# There are 87.479614 % left in this 0 epoch with average cost 0.636607
# There are 87.458267 % left in this 0 epoch with average cost 0.563004
# There are 87.436920 % left in this 0 epoch with average cost 0.559960
# There are 87.415573 % left in this 0 epoch with average cost 0.758301
# There are 87.394226 % left in this 0 epoch with average cost 0.825131
# There are 87.372879 % left in this 0 epoch with average cost 0.700197
# There are 87.351532 % left in this 0 epoch with average cost 0.746372
# There are 87.330185 % left in this 0 epoch with average cost 0.666109
# There are 87.308838 % left in this 0 epoch with average cost 0.628087
# There are 87.287492 % left in this 0 epoch with average cost 0.653628
# There are 87.266145 % left in this 0 epoch with average cost 0.638103
# There are 87.244798 % left in this 0 epoch with average cost 0.943022
# There are 87.223451 % left in this 0 epoch with average cost 0.833011
# There are 87.202104 % left in this 0 epoch with average cost 0.802041
# There are 87.180757 % left in this 0 epoch with average cost 0.785360
# There are 87.159410 % left in this 0 epoch with average cost 0.700314
# There are 87.138063 % left in this 0 epoch with average cost 0.676037
# There are 87.116716 % left in this 0 epoch with average cost 0.694887
# There are 87.095369 % left in this 0 epoch with average cost 0.743042
# There are 87.074023 % left in this 0 epoch with average cost 0.740620
# There are 87.052676 % left in this 0 epoch with average cost 0.570851
# There are 87.031329 % left in this 0 epoch with average cost 0.892974
# There are 87.009982 % left in this 0 epoch with average cost 0.805673
# There are 86.988635 % left in this 0 epoch with average cost 0.836426
# There are 86.967288 % left in this 0 epoch with average cost 0.750487
# There are 86.945941 % left in this 0 epoch with average cost 0.739653
# There are 86.924594 % left in this 0 epoch with average cost 0.785362
# There are 86.903247 % left in this 0 epoch with average cost 0.661487
# There are 86.881900 % left in this 0 epoch with average cost 0.665049
# There are 86.860553 % left in this 0 epoch with average cost 0.675648
# There are 86.839207 % left in this 0 epoch with average cost 0.652883
# There are 86.817860 % left in this 0 epoch with average cost 0.540630
# There are 86.796513 % left in this 0 epoch with average cost 0.796095
# There are 86.775166 % left in this 0 epoch with average cost 0.716253
# There are 86.753819 % left in this 0 epoch with average cost 0.681929
# There are 86.732472 % left in this 0 epoch with average cost 0.640630
# There are 86.711125 % left in this 0 epoch with average cost 0.898870
# There are 86.689778 % left in this 0 epoch with average cost 0.717279
# There are 86.668431 % left in this 0 epoch with average cost 0.644805
# There are 86.647084 % left in this 0 epoch with average cost 0.607916
# There are 86.625738 % left in this 0 epoch with average cost 0.709752
# There are 86.604391 % left in this 0 epoch with average cost 0.764090
# There are 86.583044 % left in this 0 epoch with average cost 0.586238
# There are 86.561697 % left in this 0 epoch with average cost 0.894983
# There are 86.540350 % left in this 0 epoch with average cost 0.856295
# There are 86.519003 % left in this 0 epoch with average cost 0.811279
# There are 86.497656 % left in this 0 epoch with average cost 0.783090
# There are 86.476309 % left in this 0 epoch with average cost 0.978907
# There are 86.454962 % left in this 0 epoch with average cost 0.835580
# There are 86.433615 % left in this 0 epoch with average cost 0.816658
# There are 86.412268 % left in this 0 epoch with average cost 0.680197
# There are 86.390922 % left in this 0 epoch with average cost 0.767427
# There are 86.369575 % left in this 0 epoch with average cost 0.759549
# There are 86.348228 % left in this 0 epoch with average cost 0.752636
# There are 86.326881 % left in this 0 epoch with average cost 0.705446
# There are 86.305534 % left in this 0 epoch with average cost 0.686168
# There are 86.284187 % left in this 0 epoch with average cost 0.838536
# There are 86.262840 % left in this 0 epoch with average cost 0.823851
# There are 86.241493 % left in this 0 epoch with average cost 0.673235
# There are 86.220146 % left in this 0 epoch with average cost 0.788122
# There are 86.198799 % left in this 0 epoch with average cost 0.719205
# There are 86.177453 % left in this 0 epoch with average cost 0.728235
# There are 86.156106 % left in this 0 epoch with average cost 0.658492
# There are 86.134759 % left in this 0 epoch with average cost 0.779646
# There are 86.113412 % left in this 0 epoch with average cost 0.698412
# There are 86.092065 % left in this 0 epoch with average cost 0.806676
# There are 86.070718 % left in this 0 epoch with average cost 0.708570
# There are 86.049371 % left in this 0 epoch with average cost 0.814381
# There are 86.028024 % left in this 0 epoch with average cost 0.882217
# There are 86.006677 % left in this 0 epoch with average cost 0.672217
# There are 85.985330 % left in this 0 epoch with average cost 0.814351
# There are 85.963984 % left in this 0 epoch with average cost 0.747486
# There are 85.942637 % left in this 0 epoch with average cost 0.786813
# There are 85.921290 % left in this 0 epoch with average cost 0.798433
# There are 85.899943 % left in this 0 epoch with average cost 0.588875
# There are 85.878596 % left in this 0 epoch with average cost 0.693866
# There are 85.857249 % left in this 0 epoch with average cost 0.657486
# There are 85.835902 % left in this 0 epoch with average cost 0.661893
# There are 85.814555 % left in this 0 epoch with average cost 0.946481
# There are 85.793208 % left in this 0 epoch with average cost 0.997662
# There are 85.771861 % left in this 0 epoch with average cost 0.624778
# There are 85.750514 % left in this 0 epoch with average cost 0.687489
# There are 85.729168 % left in this 0 epoch with average cost 0.895431
# There are 85.707821 % left in this 0 epoch with average cost 0.726344
# There are 85.686474 % left in this 0 epoch with average cost 0.898420
# There are 85.665127 % left in this 0 epoch with average cost 0.544387
# There are 85.643780 % left in this 0 epoch with average cost 0.658816
# ...
# There are 74.927634 % left in this 0 epoch with average cost 0.711191
# There are 74.906287 % left in this 0 epoch with average cost 0.545648
# There are 74.884940 % left in this 0 epoch with average cost 0.841985
# There are 74.863593 % left in this 0 epoch with average cost 0.825509
# There are 74.842246 % left in this 0 epoch with average cost 0.817456
# There are 74.820899 % left in this 0 epoch with average cost 0.629096
# There are 74.799553 % left in this 0 epoch with average cost 0.703804
# There are 74.778206 % left in this 0 epoch with average cost 0.940185
# There are 74.756859 % left in this 0 epoch with average cost 0.529802
# There are 74.735512 % left in this 0 epoch with average cost 0.613720
# There are 74.714165 % left in this 0 epoch with average cost 0.852351
# There are 74.692818 % left in this 0 epoch with average cost 0.733906
# There are 74.671471 % left in this 0 epoch with average cost 0.722410
# There are 74.650124 % left in this 0 epoch with average cost 0.424016
# There are 74.628777 % left in this 0 epoch with average cost 0.739437
# There are 74.607430 % left in this 0 epoch with average cost 0.666562
# There are 74.586084 % left in this 0 epoch with average cost 0.828252
# There are 74.564737 % left in this 0 epoch with average cost 0.753730
# There are 74.543390 % left in this 0 epoch with average cost 0.728348
# There are 74.522043 % left in this 0 epoch with average cost 0.894775
# There are 74.500696 % left in this 0 epoch with average cost 0.702184
# There are 74.479349 % left in this 0 epoch with average cost 0.610992
# There are 74.458002 % left in this 0 epoch with average cost 0.893234
# There are 74.436655 % left in this 0 epoch with average cost 0.720035
# There are 74.415308 % left in this 0 epoch with average cost 0.833268
# There are 74.393961 % left in this 0 epoch with average cost 0.860465
# There are 74.372614 % left in this 0 epoch with average cost 0.712194
# There are 74.351268 % left in this 0 epoch with average cost 0.688563
# There are 74.329921 % left in this 0 epoch with average cost 0.700469
# There are 74.308574 % left in this 0 epoch with average cost 0.492404
# There are 74.287227 % left in this 0 epoch with average cost 0.764077
# There are 74.265880 % left in this 0 epoch with average cost 0.655838
# There are 74.244533 % left in this 0 epoch with average cost 0.574036
# There are 74.223186 % left in this 0 epoch with average cost 0.781265
# There are 74.201839 % left in this 0 epoch with average cost 0.694243
# There are 74.180492 % left in this 0 epoch with average cost 0.894107
# There are 74.159145 % left in this 0 epoch with average cost 0.854710
# There are 74.137799 % left in this 0 epoch with average cost 0.850537
# There are 74.116452 % left in this 0 epoch with average cost 0.638640
# There are 74.095105 % left in this 0 epoch with average cost 0.742282
# There are 74.073758 % left in this 0 epoch with average cost 0.825092
# There are 74.052411 % left in this 0 epoch with average cost 0.874627
# There are 74.031064 % left in this 0 epoch with average cost 0.658011
# There are 74.009717 % left in this 0 epoch with average cost 0.800246
# There are 73.988370 % left in this 0 epoch with average cost 0.692172
# There are 73.967023 % left in this 0 epoch with average cost 0.688769
# There are 73.945676 % left in this 0 epoch with average cost 0.777206
# There are 73.924329 % left in this 0 epoch with average cost 0.860852
# There are 73.902983 % left in this 0 epoch with average cost 0.786412
# There are 73.881636 % left in this 0 epoch with average cost 0.647300
# There are 73.860289 % left in this 0 epoch with average cost 0.750959
# There are 73.838942 % left in this 0 epoch with average cost 0.773523
# There are 73.817595 % left in this 0 epoch with average cost 0.656566
# There are 73.796248 % left in this 0 epoch with average cost 0.747602
# There are 73.774901 % left in this 0 epoch with average cost 0.921861
# There are 73.753554 % left in this 0 epoch with average cost 0.579755
# There are 73.732207 % left in this 0 epoch with average cost 0.618877
# There are 73.710860 % left in this 0 epoch with average cost 0.698900
# There are 73.689514 % left in this 0 epoch with average cost 0.638774
# There are 73.668167 % left in this 0 epoch with average cost 0.635297
# There are 73.646820 % left in this 0 epoch with average cost 0.760548
# There are 73.625473 % left in this 0 epoch with average cost 0.614879
# There are 73.604126 % left in this 0 epoch with average cost 0.796380
# There are 73.582779 % left in this 0 epoch with average cost 0.605545
# There are 73.561432 % left in this 0 epoch with average cost 0.743498
# There are 73.540085 % left in this 0 epoch with average cost 0.700142
# There are 73.518738 % left in this 0 epoch with average cost 0.677178
# There are 73.497391 % left in this 0 epoch with average cost 0.687225
# There are 73.476045 % left in this 0 epoch with average cost 0.626759
# There are 73.454698 % left in this 0 epoch with average cost 0.820841
# There are 73.433351 % left in this 0 epoch with average cost 0.795008
# There are 73.412004 % left in this 0 epoch with average cost 0.745310
# There are 73.390657 % left in this 0 epoch with average cost 0.818557
# There are 73.369310 % left in this 0 epoch with average cost 0.755340
# There are 73.347963 % left in this 0 epoch with average cost 0.847707
# There are 73.326616 % left in this 0 epoch with average cost 0.739538
# There are 73.305269 % left in this 0 epoch with average cost 0.759803
# There are 73.283922 % left in this 0 epoch with average cost 0.826521
# There are 73.262575 % left in this 0 epoch with average cost 0.521741
# There are 73.241229 % left in this 0 epoch with average cost 0.691725
# There are 73.219882 % left in this 0 epoch with average cost 0.818893
# There are 73.198535 % left in this 0 epoch with average cost 0.772967
# There are 73.177188 % left in this 0 epoch with average cost 0.559018
# There are 73.155841 % left in this 0 epoch with average cost 0.914181
# There are 73.134494 % left in this 0 epoch with average cost 0.702536
# There are 73.113147 % left in this 0 epoch with average cost 0.659529
# There are 73.091800 % left in this 0 epoch with average cost 0.727187
# There are 73.070453 % left in this 0 epoch with average cost 0.726534
# There are 73.049106 % left in this 0 epoch with average cost 0.592466
# There are 73.027760 % left in this 0 epoch with average cost 0.687177
# There are 73.006413 % left in this 0 epoch with average cost 0.837942
# There are 72.985066 % left in this 0 epoch with average cost 0.937074
# There are 72.963719 % left in this 0 epoch with average cost 0.776680
# There are 72.942372 % left in this 0 epoch with average cost 0.839048
# There are 72.921025 % left in this 0 epoch with average cost 0.877398
# There are 72.899678 % left in this 0 epoch with average cost 0.861385
# There are 72.878331 % left in this 0 epoch with average cost 0.743391
# There are 72.856984 % left in this 0 epoch with average cost 0.641404
# There are 72.835637 % left in this 0 epoch with average cost 0.621235
# There are 72.814290 % left in this 0 epoch with average cost 0.858089
# There are 72.792944 % left in this 0 epoch with average cost 0.771306
# There are 72.771597 % left in this 0 epoch with average cost 0.578500
# There are 72.750250 % left in this 0 epoch with average cost 0.533900
# There are 72.728903 % left in this 0 epoch with average cost 0.701804
# There are 72.707556 % left in this 0 epoch with average cost 0.810772
# There are 72.686209 % left in this 0 epoch with average cost 0.754979
# There are 72.664862 % left in this 0 epoch with average cost 0.789023
# There are 72.643515 % left in this 0 epoch with average cost 0.705054
# There are 72.622168 % left in this 0 epoch with average cost 0.870244
# There are 72.600821 % left in this 0 epoch with average cost 0.919905
# There are 72.579475 % left in this 0 epoch with average cost 0.787465
# There are 72.558128 % left in this 0 epoch with average cost 0.759272
# There are 72.536781 % left in this 0 epoch with average cost 0.611952
# There are 72.515434 % left in this 0 epoch with average cost 0.549920
# There are 72.494087 % left in this 0 epoch with average cost 0.710564
# There are 72.472740 % left in this 0 epoch with average cost 0.631752
# There are 72.451393 % left in this 0 epoch with average cost 0.755137
# There are 72.430046 % left in this 0 epoch with average cost 0.612871
# There are 72.408699 % left in this 0 epoch with average cost 0.653136
# There are 72.387352 % left in this 0 epoch with average cost 0.654775
# There are 72.366005 % left in this 0 epoch with average cost 0.783609
# There are 72.344659 % left in this 0 epoch with average cost 0.691031
# There are 72.323312 % left in this 0 epoch with average cost 0.629411
# There are 72.301965 % left in this 0 epoch with average cost 0.819410
# There are 72.280618 % left in this 0 epoch with average cost 0.868826
# There are 72.259271 % left in this 0 epoch with average cost 0.733392
# There are 72.237924 % left in this 0 epoch with average cost 0.717786
# There are 72.216577 % left in this 0 epoch with average cost 0.676713
# There are 72.195230 % left in this 0 epoch with average cost 0.886643
# There are 72.173883 % left in this 0 epoch with average cost 0.760058
# There are 72.152536 % left in this 0 epoch with average cost 0.457866
# There are 72.131190 % left in this 0 epoch with average cost 0.670259
# There are 72.109843 % left in this 0 epoch with average cost 0.668013
# There are 72.088496 % left in this 0 epoch with average cost 0.672895
# There are 72.067149 % left in this 0 epoch with average cost 0.554213
# There are 72.045802 % left in this 0 epoch with average cost 0.840544
# There are 72.024455 % left in this 0 epoch with average cost 0.712735
# There are 72.003108 % left in this 0 epoch with average cost 0.637915
# There are 71.981761 % left in this 0 epoch with average cost 0.621723
# There are 71.960414 % left in this 0 epoch with average cost 0.864332
# There are 71.939067 % left in this 0 epoch with average cost 0.701628
# There are 71.917720 % left in this 0 epoch with average cost 0.663776
# There are 71.896374 % left in this 0 epoch with average cost 0.884932
# There are 71.875027 % left in this 0 epoch with average cost 0.822217
# There are 71.853680 % left in this 0 epoch with average cost 0.723912
# There are 71.832333 % left in this 0 epoch with average cost 0.783953
# There are 71.810986 % left in this 0 epoch with average cost 0.911640
# There are 71.789639 % left in this 0 epoch with average cost 0.817904
# There are 71.768292 % left in this 0 epoch with average cost 0.717710
# There are 71.746945 % left in this 0 epoch with average cost 0.788245
# There are 71.725598 % left in this 0 epoch with average cost 0.796269
# There are 71.704251 % left in this 0 epoch with average cost 0.733020
# There are 71.682905 % left in this 0 epoch with average cost 0.793562
# There are 71.661558 % left in this 0 epoch with average cost 0.660006
# There are 71.640211 % left in this 0 epoch with average cost 0.575405
# There are 71.618864 % left in this 0 epoch with average cost 0.731150
# There are 71.597517 % left in this 0 epoch with average cost 0.822565
# There are 71.576170 % left in this 0 epoch with average cost 0.701338
# There are 71.554823 % left in this 0 epoch with average cost 0.886231
# There are 71.533476 % left in this 0 epoch with average cost 0.692957
# There are 71.512129 % left in this 0 epoch with average cost 0.708340
# There are 71.490782 % left in this 0 epoch with average cost 0.722001
# There are 71.469436 % left in this 0 epoch with average cost 0.803840
# There are 71.448089 % left in this 0 epoch with average cost 0.774001
# There are 71.426742 % left in this 0 epoch with average cost 0.710200
# There are 71.405395 % left in this 0 epoch with average cost 0.772199
# There are 71.384048 % left in this 0 epoch with average cost 0.642198
# There are 71.362701 % left in this 0 epoch with average cost 0.725075
# There are 71.341354 % left in this 0 epoch with average cost 0.856068
# There are 71.320007 % left in this 0 epoch with average cost 0.703838
# There are 71.298660 % left in this 0 epoch with average cost 0.832013
# There are 71.277313 % left in this 0 epoch with average cost 0.648359
# There are 71.255966 % left in this 0 epoch with average cost 0.936382
# There are 71.234620 % left in this 0 epoch with average cost 0.574600
# There are 71.213273 % left in this 0 epoch with average cost 0.855610
# There are 71.191926 % left in this 0 epoch with average cost 0.596023
# There are 71.170579 % left in this 0 epoch with average cost 0.857048
# There are 71.149232 % left in this 0 epoch with average cost 0.630264
# There are 71.127885 % left in this 0 epoch with average cost 0.711289
# There are 71.106538 % left in this 0 epoch with average cost 0.638437
# There are 71.085191 % left in this 0 epoch with average cost 0.627780
# There are 71.063844 % left in this 0 epoch with average cost 0.795755
# There are 71.042497 % left in this 0 epoch with average cost 0.634094
# There are 71.021151 % left in this 0 epoch with average cost 0.729362
# There are 70.999804 % left in this 0 epoch with average cost 0.672269
# There are 70.978457 % left in this 0 epoch with average cost 0.823086
# There are 70.957110 % left in this 0 epoch with average cost 0.740150
# There are 70.935763 % left in this 0 epoch with average cost 0.738043
# There are 70.914416 % left in this 0 epoch with average cost 0.974472
# There are 70.893069 % left in this 0 epoch with average cost 0.600587
# There are 70.871722 % left in this 0 epoch with average cost 0.718173
# There are 70.850375 % left in this 0 epoch with average cost 0.598246
# There are 70.829028 % left in this 0 epoch with average cost 0.872026
# There are 70.807681 % left in this 0 epoch with average cost 0.707529
# There are 70.786335 % left in this 0 epoch with average cost 0.737708
# There are 70.764988 % left in this 0 epoch with average cost 0.609490
# There are 70.743641 % left in this 0 epoch with average cost 0.681273
# There are 70.722294 % left in this 0 epoch with average cost 0.963481
# There are 70.700947 % left in this 0 epoch with average cost 0.842836
# There are 70.679600 % left in this 0 epoch with average cost 0.977962
# There are 70.658253 % left in this 0 epoch with average cost 0.930543
# There are 70.636906 % left in this 0 epoch with average cost 1.021395
# There are 70.615559 % left in this 0 epoch with average cost 1.228368
# There are 70.594212 % left in this 0 epoch with average cost 0.905343
# There are 70.572866 % left in this 0 epoch with average cost 1.092895
# There are 70.551519 % left in this 0 epoch with average cost 1.449797
# There are 70.530172 % left in this 0 epoch with average cost 0.836750
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 380>()
#     380 if __name__ == "__main__":
#     381 #     arg = ["", "Data/Query_Apple/2005-2010/IndexedEvents.npy",
#     382 #           "Data/Query_Apple/2005-2010/linhtinh/", "20"]
#     383 #     arg = sys.argv
#     384     arg = ["", "/Users/arthur/Desktop/OpenIEStanza_EventEmbedding/input/event2index2.npy",
#     385           "/Users/arthur/Desktop/OpenIEStanza_EventEmbedding/input/", "1"]
# --> 386     main(dataPath=arg[1], trainedParamsPath=arg[2]+"TrainedParams2.pickle",
#     387          outputVectorPath=arg[2]+"resultEmbeding2.pickle", n_epochs=int(arg[3]), word_dim=100)
#
# Input In [6], in main(dataPath, trainedParamsPath, outputVectorPath, learning_rate, L2_reg, n_epochs, num_K, word_dim)
#     356 if cost > 0:
#     357     set_index.add(index)
# --> 358     c = TRAIN(ob1_real, ob1_fake, act, obj2)
#     359 else:
#     360     RESULT[index] = GET_EVENT_VECTOR(ob1_real, ob1_fake, act, obj2)
#
# File /opt/anaconda3/lib/python3.9/site-packages/theano/compile/function_module.py:903, in Function.__call__(self, *args, **kwargs)
#     900 t0_fn = time.time()
#     901 try:
#     902     outputs =\
# --> 903         self.fn() if output_subset is None else\
#     904         self.fn(output_subset=output_subset)
#     905 except Exception:
#     906     restore_defaults()
#
# KeyboardInterrupt:

# %% [markdown]
# # RoleDependentLayer.py

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sat Mar 25 16:13:18 2017

@author: red-sky
"""

import theano
import numpy as np
import theano.tensor as T
from SmallUtils import createShareVar


class RoleDependentLayer(object):
    def __init__(self, left_dependent, right_dependent, rng,
                 n_in=100, n_out=4, trainedParams=None,
                 name="RoleDependentEmbedding_"):
        if trainedParams is None:
            trainedParams = {
                name: {
                    "T": None, "W1": None, "W2": None, "b": None
                }
            }
#        print(name)
        if trainedParams[name]["T"] is not None:
#            print(trainedParams[name]["T"])
#            print(trainedParams[name]["T"].shape)
#            print(n_out, n_in, n_in)
            assert trainedParams[name]["T"].shape == (n_out, n_in, n_in)
            self.T = theano.shared(value=trainedParams[name]["T"],
                                   name=name+"T", borrow=True)
        else:
            self.T = createShareVar(rng=rng, name=name+"T",
                                    factor_for_init=n_out + n_in,
                                    dim=(n_out, n_in, n_in))

        if trainedParams[name]["W1"] is not None:
            assert trainedParams[name]["W1"].shape == (n_in, n_out)
            self.W1 = theano.shared(value=trainedParams[name]["W1"],
                                    name=name+"W1", borrow=True)
        else:
            self.W1 = createShareVar(rng=rng, name=name+"W1",
                                     factor_for_init=n_out + n_in,
                                     dim=(n_in, n_out))

        if trainedParams[name]["W2"] is not None:
            assert trainedParams[name]["W2"].shape == (n_in, n_out)
            self.W2 = theano.shared(value=trainedParams[name]["W2"],
                                    name=name+"W2", borrow=True)
        else:
            self.W2 = createShareVar(rng=rng, name=name+"W2",
                                     factor_for_init=n_out + n_in,
                                     dim=(n_in, n_out))

        if trainedParams[name]["b"] is not None:
            assert trainedParams[name]["b"].shape == (n_out,)
            self.b = theano.shared(value=trainedParams[name]["b"],
                                   name=name+"b", borrow=True)
        else:
            b_values = np.zeros(shape=(n_out,), dtype=theano.config.floatX)
            self.b = theano.shared(value=b_values, name=name+"b", borrow=True)

        # list of layer params
        self.params = [self.T, self.W1, self.W2, self.b]

        # L2 regulation
        self.L2 = sum([(param**2).sum() for param in self.params])

        # Bi-linear step
        def one_kernel(Tk, left, right):
            first_bi_libear = theano.dot(left, Tk)
            seccon_bi_linear = theano.dot(first_bi_libear, right)
            return(seccon_bi_linear.flatten())

        bi_1, _ = theano.scan(
            fn=one_kernel,
            sequences=[self.T],
            non_sequences=[left_dependent, right_dependent],
            n_steps=n_out
        )

        # Feed forward network step
        feedforward_step1 = theano.dot(left_dependent, self.W1)
        feedforward_step2 = theano.dot(right_dependent, self.W2)
        feedforward_step3 = (feedforward_step1 +
                             feedforward_step2.dimshuffle("x", 0) +
                             self.b.dimshuffle("x", 0))
        feedforward_step4 = bi_1.dimshuffle(1, 0) + feedforward_step3
        self.output = theano.tensor.tanh(feedforward_step4)
        self.test = [feedforward_step3]

    def output_(self, left_dependent, right_dependent):

        def one_kernel(Tk, left, right):
            first_bi_libear = theano.dot(left, Tk)
            seccon_bi_linear = theano.dot(first_bi_libear, right)
            return(seccon_bi_linear.flatten())

        bi_linear_tensor, _ = theano.scan(
            fn=one_kernel,
            sequences=[self.T],
            non_sequences=[left_dependent, right_dependent],
            n_steps=n_out
        )

        bi_linear_tensor = bi_linear_tensor.dimshuffle(1, 0)
        feedforward_step1 = theano.dot(left_dependent, self.W1)
        feedforward_step2 = theano.dot(right_dependent, self.W2)
        feedforward_step3 = (feedforward_step1 +
                             feedforward_step2.dimshuffle("x", 0) +
                             self.b.dimshuffle("x", 0))
        feedforward_step4 = bi_linear_tensor + feedforward_step3
        output = theano.tensor.tanh(feedforward_step4)
        return(output)

    def get_params(self):
        trainedParams = {
            "T": self.T.get_value(), "W1": self.W1.get_value(),
            "W2": self.W2.get_value(), "b": self.b.get_value()
        }
        return(trainedParams)

# %% [markdown]
# # SmallUtils.py

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sat Mar 25 15:55:14 2017

@author: red-sky
"""
import theano
import theano.tensor as T
import numpy as np

def createShareVar(rng, dim, name, factor_for_init):
    var_values = np.asarray(
        rng.uniform(
            low=-np.sqrt(6.0 / factor_for_init),
            high=np.sqrt(6.0 / factor_for_init),
            size=dim,
        )
    )
    Var = theano.shared(value=var_values, name=name, borrow=True)
    return Var


def adadelta(lr, tparams, cost, grads, listInput):
    """
    An adaptive learning rate optimizer

    Parameters
    ----------
    lr : Theano SharedVariable
        Initial learning rate
    tpramas: Theano SharedVariable
        Model parameters
    grads: Theano variable
        Gradients of cost w.r.t to parameres

    cost: Theano variable
        Objective fucntion to minimize

    Notes
    -----
    For more information, see [ADADELTA]_.

    .. [ADADELTA] Matthew D. Zeiler, *ADADELTA: An Adaptive Learning
       Rate Method*, arXiv:1212.5701.
    """
    np_float = np.asarray(0., dtype=theano.config.floatX)
    zipped_grads = [theano.shared(p.get_value() * np_float,
                                  name='%s_grad' % k)
                    for k, p in enumerate(tparams)]
    running_up2 = [theano.shared(p.get_value() * np_float,
                                 name='%s_rup2' % k)
                   for k, p in enumerate(tparams)]
    running_grads2 = [theano.shared(p.get_value() * np_float,
                                    name='%s_rgrad2' % k)
                      for k, p in enumerate(tparams)]

    zgup = [(zg, g) for zg, g in zip(zipped_grads, grads)]
    rg2up = [(rg2, 0.95 * rg2 + 0.05 * (g ** 2))
             for rg2, g in zip(running_grads2, grads)]

    f_grad_shared = theano.function(inputs=listInput,
                                    outputs=cost,
                                    updates=zgup + rg2up,
                                    name='adadelta_f_grad_shared')

    updir = [-T.sqrt(ru2 + 1e-6) / T.sqrt(rg2 + 1e-6) * zg
             for zg, ru2, rg2 in zip(zipped_grads,
                                     running_up2,
                                     running_grads2)]
    ru2up = [(ru2, 0.95 * ru2 + 0.05 * (ud ** 2))
             for ru2, ud in zip(running_up2, updir)]
    param_up = [(p, p + ud) for p, ud in zip(tparams, updir)]

    f_update = theano.function([lr], [], updates=ru2up + param_up,
                               on_unused_input='ignore',
                               name='adadelta_f_update')

    return f_grad_shared, f_update


def ADAM_OPTIMIZER(loss, all_params, learning_rate=0.001,
                   b1=0.9, b2=0.999, e=1e-8, gamma=1-1e-8):
    """
    CITE: http://sebastianruder.com/optimizing-gradient-descent/index.html#adam
    ADAM update rules
    Default values are taken from [Kingma2014]
    References:
    [Kingma2014] Kingma, Diederik, and Jimmy Ba.
    "Adam: A Method for Stochastic Optimization."
    arXiv preprint arXiv:1412.6980 (2014).
    http://arxiv.org/pdf/1412.6980v4.pdf
    """
    updates = []
    all_grads = theano.grad(loss, all_params)
    alpha = learning_rate
    t = theano.shared(np.float32(1))
    # (Decay the first moment running average coefficient)
    b1_t = b1*gamma**(t-1)

    for params_previous, g in zip(all_params, all_grads):
        init_moment = np.zeros(params_previous.get_value().shape,
                               dtype=theano.config.floatX)
        # (the mean)
        first_moment = theano.shared(init_moment)
        # (the uncentered variance)
        second_moment = theano.shared(init_moment)

        # (Update biased first moment estimate)
        bias_m = b1_t*first_moment + (1 - b1_t)*g

        # (Update biased second raw moment estimate)
        bias_v = b2*second_moment + (1 - b2)*g**2

        # (Compute bias-corrected first moment estimate)
        unbias_m = bias_m / (1-b1**t)

        # (Compute bias-corrected second raw moment estimate)
        unbias_v = bias_v / (1-b2**t)

        # (Update parameters)
        update_term = (alpha * unbias_m) / (T.sqrt(unbias_v) + e)
        params_new = params_previous - update_term

        updates.append((first_moment, bias_m))
        updates.append((second_moment, bias_v))
        updates.append((params_previous, params_new))
    updates.append((t, t + 1.))
    return updates

# %% [markdown]
# ## 下面不用了

# %%
import os
import numpy as np
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor, Lambda
# pip install torchvision

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits
model = NeuralNetwork().to(device)
print(model)
# Out:
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork()

# %%
X = torch.rand(1, 28, 28, device=device)
logits = model(X)
pred_probab = nn.Softmax(dim=1)(logits)
y_pred = pred_probab.argmax(1)
print(f"Predicted class: {y_pred}")
# Out:
# Predicted class: tensor([2])

# %%
X
X[0, 0, 1]
# Out:
# tensor(0.9494)

# %%
#1
input_image = torch.rand(3,28,28)
print(input_image.size())

#2
flatten = nn.Flatten()
flat_image = flatten(input_image)
print(flat_image.size())

#3
layer1 = nn.Linear(in_features=28*28, out_features=20)
hidden1 = layer1(flat_image)
print(hidden1.size())

#4
print(f"Before ReLU: {hidden1}\n\n")
hidden1 = nn.ReLU()(hidden1)
print(f"After ReLU: {hidden1}")

#5
seq_modules = nn.Sequential(
    flatten,
    layer1,
    nn.ReLU(),
    nn.Linear(20, 10)
)
input_image = torch.rand(3,28,28)
logits = seq_modules(input_image)

#6
softmax = nn.Softmax(dim=1)
pred_probab = softmax(logits)
print(pred_probab)

#7
print(f"Model structure: {model}\n\n")

for name, param in model.named_parameters():
    print(f"Layer: {name} | Size: {param.size()} | Values : {param[:2]} \n")
# Out:
# torch.Size([3, 28, 28])
# torch.Size([3, 784])
# torch.Size([3, 20])
# Before ReLU: tensor([[ 0.0305, -0.5532,  0.7130,  0.8898,  0.0230, -0.2422, -0.2477, -0.2424,
#          -0.0642, -0.1797,  0.2153,  0.0757,  0.2777,  0.0609,  0.1148, -0.9117,
#           0.3570, -0.4060,  0.4346,  0.3369],
#         [ 0.1104, -0.2133,  0.6152,  0.4745, -0.0112,  0.0866, -0.3030, -0.4700,
#           0.0877, -0.2403,  0.0436,  0.0757,  0.0117, -0.0613, -0.1673, -0.9643,
#           0.4333, -0.3328,  0.6907,  0.1493],
#         [ 0.0368, -0.3006,  0.8761,  0.7100,  0.0723,  0.3564, -0.4708, -0.2543,
#          -0.0399, -0.2391,  0.0966,  0.3240,  0.1662,  0.2291, -0.1094, -0.9933,
#           0.5804, -0.2566,  0.5009,  0.3386]], grad_fn=<AddmmBackward0>)
#
#
# After ReLU: tensor([[0.0305, 0.0000, 0.7130, 0.8898, 0.0230, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.2153, 0.0757, 0.2777, 0.0609, 0.1148, 0.0000, 0.3570, 0.0000,
#          0.4346, 0.3369],
#         [0.1104, 0.0000, 0.6152, 0.4745, 0.0000, 0.0866, 0.0000, 0.0000, 0.0877,
#          0.0000, 0.0436, 0.0757, 0.0117, 0.0000, 0.0000, 0.0000, 0.4333, 0.0000,
#          0.6907, 0.1493],
#         [0.0368, 0.0000, 0.8761, 0.7100, 0.0723, 0.3564, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0966, 0.3240, 0.1662, 0.2291, 0.0000, 0.0000, 0.5804, 0.0000,
#          0.5009, 0.3386]], grad_fn=<ReluBackward0>)
# tensor([[0.0916, 0.0760, 0.0795, 0.0697, 0.1097, 0.1012, 0.1551, 0.1022, 0.1074,
#          0.1075],
#         [0.0884, 0.0728, 0.0745, 0.0833, 0.0904, 0.1053, 0.1806, 0.0951, 0.1093,
#          0.1003],
#         [0.1019, 0.0840, 0.0835, 0.0766, 0.0942, 0.1075, 0.1559, 0.0945, 0.1019,
#          0.1000]], grad_fn=<SoftmaxBackward0>)
# Model structure: NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#   )
# )
#
#
# Layer: linear_relu_stack.0.weight | Size: torch.Size([512, 784]) | Values : tensor([[-0.0278, -0.0029, -0.0026,  ..., -0.0011,  0.0008, -0.0103],
#         [-0.0207, -0.0309, -0.0325,  ..., -0.0024,  0.0353,  0.0223]],
#        grad_fn=<SliceBackward0>)
#
# Layer: linear_relu_stack.0.bias | Size: torch.Size([512]) | Values : tensor([-0.0221, -0.0049], grad_fn=<SliceBackward0>)
#
# Layer: linear_relu_stack.2.weight | Size: torch.Size([512, 512]) | Values : tensor([[ 0.0265, -0.0220, -0.0271,  ..., -0.0243,  0.0243,  0.0360],
#         [ 0.0110,  0.0302,  0.0324,  ..., -0.0389,  0.0366, -0.0109]],
#        grad_fn=<SliceBackward0>)
#
# Layer: linear_relu_stack.2.bias | Size: torch.Size([512]) | Values : tensor([-0.0161, -0.0179], grad_fn=<SliceBackward0>)
#
# Layer: linear_relu_stack.4.weight | Size: torch.Size([10, 512]) | Values : tensor([[ 0.0042, -0.0386,  0.0256,  ...,  0.0322,  0.0016, -0.0384],
#         [ 0.0287,  0.0423,  0.0075,  ...,  0.0424,  0.0320, -0.0349]],
#        grad_fn=<SliceBackward0>)
#
# Layer: linear_relu_stack.4.bias | Size: torch.Size([10]) | Values : tensor([-0.0310, -0.0181], grad_fn=<SliceBackward0>)

# %%
torch.tensor(np.array([2, 1]))
# Out:
# tensor([2, 1])

# %%
O1 = torch.rand(50,100,1)
P = torch.rand(50,100,1)
O2 = torch.rand(50,100,1)

# %%
pwd
# Out:
# '/Users/arthur/Desktop/OpenIEStanza_EventEmbedding'
